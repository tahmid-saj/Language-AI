# %% [markdown]
# # NLP text classification analysis

# %%
# !pip install confuse
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting confuse
#   Downloading confuse-2.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from confuse) (6.0)
# Installing collected packages: confuse
# Successfully installed confuse-2.0.0

# %% [markdown]
# Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import random
import zipfile

import logging
import confuse
import os
from datetime import datetime, timedelta
#from pyspark.sql.functions import *
#import pyspark.sql.functions as f
#import sparknlp
#from sparknlp.base import *

#from pyspark.sql.types import *
#from pyspark.sql.window import Window
#from pyspark.sql.functions import substring_index
#from sparknlp.base import *
#from sparknlp.annotator import *
import re
import string
#from sparknlp.pretrained import PretrainedPipeline
#import spacy
#import en_core_web_md

from sklearn.model_selection import train_test_split
from tensorflow.keras import layers
from statistics import mean
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

# %% [markdown]
# Constants

# %%
BATCH_SIZE = 32
VOCAB_LENGTH = 15000

# %% [markdown]
# ## Text data loading & ETL

# %%
train_df = pd.read_csv("train_dataset.csv")[["text", "target"]]
test_df = pd.read_csv("test_dataset.csv")[["text"]]
print(train_df.head())
# Out:
#                                                 text  target
# 0  Our Deeds are the Reason of this #earthquake M...       1
# 1             Forest fire near La Ronge Sask. Canada       1
# 2  All residents asked to 'shelter in place' are ...       1
# 3  13,000 people receive #wildfires evacuation or...       1
# 4  Just got sent this photo from Ruby #Alaska as ...       1

# %%
print(test_df.head())
# Out:
#                                                 text
# 0                 Just happened a terrible car crash
# 1  Heard about #earthquake is different cities, s...
# 2  there is a forest fire at spot pond, geese are...
# 3           Apocalypse lighting. #Spokane #wildfires
# 4      Typhoon Soudelor kills 28 in China and Taiwan

# %%
print(f"Value counts of test dataset: {train_df.target.value_counts()}")
# Out:
# Value counts of test dataset: 0    4342
# 1    3271
# Name: target, dtype: int64

# %%
train_text, val_text, train_label, val_label = train_test_split(train_df["text"].to_numpy(), 
                                                                train_df["target"].to_numpy(), 
                                                                test_size=0.1, 
                                                                random_state=42)

print(train_text.shape, val_text.shape, train_label.shape, val_label.shape)
# Out:
# (6851,) (762,) (6851,) (762,)

# %%
print(train_text[:5])
# Out:
# ["'McFadden Reportedly to Test Hamstring Thursday' via @TeamStream http://t.co/jWq4KvJH2j"
#  'w--=-=-=-[ NEMA warns Nigerians to prepare for drought http://t.co/5uoOPhSqU3'
#  "When I was cooking earlier I got electrocuted some crucial ?????? now I'm psychic lol"
#  "I'm On Fire.  http://t.co/WATsmxYTVa"
#  "More than 40 families affected by the fatal outbreak of Legionnaires' disease in Edinburgh are to sue two comp... http://t.co/vsoXioOy78"]

# %%
print(train_label[:5])
# Out:
# [0 1 0 0 1]

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Tokenization

# %%
mean_word_length = int(mean([len(w.split()) for w in train_text]))

# %%
tokenizer = layers.TextVectorization(max_tokens=VOCAB_LENGTH, standardize="lower_and_strip_punctuation", split="whitespace", ngrams=None, output_mode="int", output_sequence_length=mean_word_length)
tokenizer.adapt(train_text)

# %%
vocab = tokenizer.get_vocabulary()
frequent_words = vocab[:10]
unfrequent_words = vocab[-10:]
print(f"Frequent words: {frequent_words}\n Unfrequent words: {unfrequent_words}")
# Out:
# Frequent words: ['', '[UNK]', 'the', 'a', 'in', 'to', 'of', 'and', 'i', 'is']
#  Unfrequent words: ['httptcoeejrmktj0r', 'httptcoeeewo207mx', 'httptcoee8rpoahpk', 'httptcoedznx6goud', 'httptcoedekrmqtpq', 'httptcoed32pbvio7', 'httptcoed1vpitswy', 'httptcoecxmoinzgu', 'httptcoecmj18azai', 'httptcoecd7hizja1']

# %% [markdown]
# ### Dense model

# %%
class DenseModel():
    def __init__(self, tokenizer, n_units=1, activation="sigmoid"):
        self.tokenizer = tokenizer
        self.n_units = n_units
        self.activation = activation
    
    def get_model(self, model_name="dense_model"):
        dense_inputs = layers.Input(shape=(1, ), dtype="string")
        
        x = self.tokenizer(dense_inputs)
        dense_embedding = layers.Embedding(input_dim=len(vocab), 
                                           output_dim=128, 
                                           embeddings_initializer="uniform", 
                                           input_length=mean_word_length, 
                                           name="embedding")
        x = dense_embedding(x)
        
        x = layers.GlobalAveragePooling1D()(x)
        dense_outputs = layers.Dense(units=self.n_units, activation=self.activation)(x)
        dense_model = tf.keras.Model(dense_inputs, dense_outputs, name=model_name)
        
        return dense_model

# %% [markdown]
# ### LSTM model

# %%
class LSTMModel():
    def __init__(self, tokenizer, vocab, mean_word_length, embedding_output_dim=128, n_lstm_units=64, n_dense_units=1, activation="sigmoid"):
        self.tokenizer = tokenizer
        self.vocab = vocab
        self.mean_word_length = mean_word_length
        self.embedding_output_dim = embedding_output_dim
        self.n_lstm_units = n_lstm_units
        self.n_dense_units = n_dense_units
        self.activation = activation
        
        self.embedding_input_dim = len(vocab)
        
    def get_model(self, model_name="lstm_model"):
        tf.random.set_seed(42)
        
        lstm_embedding = layers.Embedding(input_dim=self.embedding_input_dim, 
                                          output_dim=self.embedding_output_dim, 
                                          embeddings_initializer="uniform",
                                          input_length=self.mean_word_length,
                                          name="embedding-lstm")
        
        lstm_inputs = layers.Input(shape=(1, ), dtype="string")
        x = self.tokenizer(lstm_inputs)
        x = lstm_embedding(x)
        x = layers.LSTM(units=self.n_lstm_units)(x)
        lstm_outputs = layers.Dense(units=self.n_dense_units, activation=self.activation)(x)
        lstm_model = tf.keras.Model(lstm_inputs, lstm_outputs, name=model_name)
        
        return lstm_model

# %% [markdown]
# ### Bidirectional LSTM model

# %%
class BidirectionalLSTMModel():
    def __init__(self, tokenizer, vocab, mean_word_length, embedding_output_dim=128, n_lstm_units=64, n_dense_units=1, activation="sigmoid"):
        self.tokenizer = tokenizer
        self.vocab = vocab
        self.mean_word_length = mean_word_length
        self.embedding_output_dim = embedding_output_dim
        self.n_lstm_units = n_lstm_units
        self.n_dense_units = n_dense_units
        self.activation = activation
        
        self.embedding_input_dim = len(vocab)
        
    def get_model(self, model_name="bidirectional_lstm_model"):
        tf.random.set_seed(42)
        
        bidir_lstm_embedding = layers.Embedding(input_dim=self.embedding_input_dim,
                                               output_dim=self.embedding_output_dim,
                                               embeddings_initializer="uniform",
                                               input_length=self.mean_word_length,
                                               name="embedding-bidirectional-lstm")
        bidir_lstm_inputs = layers.Input(shape=(1, ), dtype="string")
        x = self.tokenizer(bidir_lstm_inputs)
        x = bidir_lstm_embedding(x)
        x = layers.Bidirectional(layers.LSTM(units=self.n_lstm_units))(x)
        bidir_lstm_outputs = layers.Dense(units=1, activation="sigmoid")(x)
        bidir_lstm_model = tf.keras.Model(bidir_lstm_inputs, bidir_lstm_outputs, name=model_name)
        
        return bidir_lstm_model

# %% [markdown]
# ### Ensemble modeling

# %%
def get_ensemble_models(models, train_data, train_label, val_data, num_iter=10, num_epochs=100, loss_funcs=["binary_crossentropy"]):
    """
    Returns a list of num_iter models each trained on binary_crossentropy loss functions by default.
    
    For instance, if num_iter = 10, a list of 60 trained models will be returned.
    10 * len(loss_funcs) * len(models) = 60 
    
    Parameters
    ----------
    models: NLP models passed.
    train_data: Training text dataset before tokenization and embedding.
    train_label: Training label dataset.
    val_data: List of validation dataset before tokenization and embedding.
    """
    ensemble_models = []
    
    for n_iter in range(num_iter):
        for model in models:
            for loss_func in loss_funcs:
                print(f"Reducing: {loss_func} for epochs: {num_epochs}, num_iter: {n_iter}, model: {model.name}")
                
                model.compile(loss=loss_func, optimizer=tf.keras.optimizers.Adam(), metrics=["accuracy"])
                
                model.fit(train_data, train_label, epochs=num_epochs, verbose=2, validation_data=val_data,
                         callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=200, restore_best_weights=True),
                                     tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=100, verbose=1)])
                
                ensemble_models.append(model)
    
    return ensemble_models

# %%
def make_ensemble_preds(ensemble_models, input_data):
    """
    Returns predictions of ensemble models.

    Parameters
    ----------
    ensemble_models: Trained ensemble of models.
    input_data: Data to be predicted with.
    """
    ensemble_preds = []
    
    for model in ensemble_models:
        preds = model.predict(input_data) # Make predictions with current ensemble model
        ensemble_preds.append(preds)
    
    return tf.constant(tf.squeeze(ensemble_preds))

# %%
def get_ensemble_models_summary(models):
    """
    Generates model summaries of ensemble models.

    Parameters
    ----------
    models: Ensemble of models.
    """
    for model in models:
        print(model.summary())

# %% [markdown]
# ### Training ensemble models

# %%
dense_model_obj = DenseModel(tokenizer=tokenizer)
dense_model = dense_model_obj.get_model()

lstm_model_obj = LSTMModel(tokenizer=tokenizer, vocab=vocab, mean_word_length=mean_word_length)
lstm_model = lstm_model_obj.get_model()

bidir_lstm_model_obj = BidirectionalLSTMModel(tokenizer=tokenizer, vocab=vocab, mean_word_length=mean_word_length)
bidir_lstm_model = bidir_lstm_model_obj.get_model()

ensemble_models = [dense_model, lstm_model, bidir_lstm_model]

# %%
ensemble_models = get_ensemble_models(models=ensemble_models, 
                                      train_data=train_text, 
                                      train_label=train_label, 
                                      val_data=(val_text, val_label), 
                                      num_iter=10, num_epochs=100)
# Out:
# Reducing: binary_crossentropy for epochs: 100, num_iter: 0, model: dense_model
# Epoch 1/100
# 215/215 - 7s - loss: 0.6087 - accuracy: 0.6990 - val_loss: 0.5379 - val_accuracy: 0.7730 - lr: 0.0010 - 7s/epoch - 34ms/step
# Epoch 2/100
# 215/215 - 4s - loss: 0.4301 - accuracy: 0.8253 - val_loss: 0.4847 - val_accuracy: 0.7913 - lr: 0.0010 - 4s/epoch - 19ms/step
# Epoch 3/100
# 215/215 - 4s - loss: 0.3269 - accuracy: 0.8726 - val_loss: 0.4813 - val_accuracy: 0.7874 - lr: 0.0010 - 4s/epoch - 18ms/step
# Epoch 4/100
# 215/215 - 5s - loss: 0.2561 - accuracy: 0.9056 - val_loss: 0.4996 - val_accuracy: 0.7743 - lr: 0.0010 - 5s/epoch - 23ms/step
# Epoch 5/100
# 215/215 - 4s - loss: 0.2033 - accuracy: 0.9285 - val_loss: 0.5198 - val_accuracy: 0.7756 - lr: 0.0010 - 4s/epoch - 19ms/step
# Epoch 6/100
# 215/215 - 5s - loss: 0.1636 - accuracy: 0.9437 - val_loss: 0.5496 - val_accuracy: 0.7769 - lr: 0.0010 - 5s/epoch - 21ms/step
# Epoch 7/100
# 215/215 - 5s - loss: 0.1329 - accuracy: 0.9558 - val_loss: 0.5831 - val_accuracy: 0.7612 - lr: 0.0010 - 5s/epoch - 24ms/step
# Epoch 8/100
# 215/215 - 5s - loss: 0.1093 - accuracy: 0.9645 - val_loss: 0.6168 - val_accuracy: 0.7454 - lr: 0.0010 - 5s/epoch - 21ms/step
# Epoch 9/100
# 215/215 - 4s - loss: 0.0917 - accuracy: 0.9714 - val_loss: 0.6493 - val_accuracy: 0.7493 - lr: 0.0010 - 4s/epoch - 18ms/step
# Epoch 10/100
# 215/215 - 5s - loss: 0.0778 - accuracy: 0.9764 - val_loss: 0.6900 - val_accuracy: 0.7480 - lr: 0.0010 - 5s/epoch - 23ms/step
# Epoch 11/100
# 215/215 - 5s - loss: 0.0665 - accuracy: 0.9810 - val_loss: 0.7187 - val_accuracy: 0.7546 - lr: 0.0010 - 5s/epoch - 24ms/step
# Epoch 12/100
# 215/215 - 4s - loss: 0.0590 - accuracy: 0.9823 - val_loss: 0.7632 - val_accuracy: 0.7402 - lr: 0.0010 - 4s/epoch - 19ms/step
# Epoch 13/100
# 215/215 - 5s - loss: 0.0518 - accuracy: 0.9854 - val_loss: 0.8057 - val_accuracy: 0.7270 - lr: 0.0010 - 5s/epoch - 22ms/step
# Epoch 14/100
# 215/215 - 6s - loss: 0.0464 - accuracy: 0.9857 - val_loss: 0.8372 - val_accuracy: 0.7297 - lr: 0.0010 - 6s/epoch - 29ms/step
# Epoch 15/100
# 215/215 - 8s - loss: 0.0428 - accuracy: 0.9866 - val_loss: 0.8753 - val_accuracy: 0.7349 - lr: 0.0010 - 8s/epoch - 37ms/step
# Epoch 16/100
# 215/215 - 5s - loss: 0.0388 - accuracy: 0.9866 - val_loss: 0.9070 - val_accuracy: 0.7362 - lr: 0.0010 - 5s/epoch - 24ms/step
# Epoch 17/100
# 215/215 - 4s - loss: 0.0375 - accuracy: 0.9876 - val_loss: 0.9412 - val_accuracy: 0.7283 - lr: 0.0010 - 4s/epoch - 20ms/step
# Epoch 18/100
# 215/215 - 6s - loss: 0.0339 - accuracy: 0.9882 - val_loss: 0.9783 - val_accuracy: 0.7428 - lr: 0.0010 - 6s/epoch - 26ms/step
# Epoch 19/100
# 215/215 - 6s - loss: 0.0326 - accuracy: 0.9864 - val_loss: 1.0147 - val_accuracy: 0.7388 - lr: 0.0010 - 6s/epoch - 27ms/step
# Epoch 20/100
# 215/215 - 4s - loss: 0.0311 - accuracy: 0.9874 - val_loss: 1.0518 - val_accuracy: 0.7336 - lr: 0.0010 - 4s/epoch - 19ms/step
# Epoch 21/100
# 215/215 - 5s - loss: 0.0300 - accuracy: 0.9876 - val_loss: 1.0645 - val_accuracy: 0.7480 - lr: 0.0010 - 5s/epoch - 24ms/step
# Epoch 22/100
# 215/215 - 4s - loss: 0.0288 - accuracy: 0.9876 - val_loss: 1.1057 - val_accuracy: 0.7362 - lr: 0.0010 - 4s/epoch - 20ms/step
# Epoch 23/100
# 215/215 - 4s - loss: 0.0285 - accuracy: 0.9876 - val_loss: 1.1211 - val_accuracy: 0.7507 - lr: 0.0010 - 4s/epoch - 18ms/step
# Epoch 24/100
# 215/215 - 4s - loss: 0.0280 - accuracy: 0.9877 - val_loss: 1.1469 - val_accuracy: 0.7231 - lr: 0.0010 - 4s/epoch - 18ms/step
# Epoch 25/100
# 215/215 - 5s - loss: 0.0267 - accuracy: 0.9885 - val_loss: 1.1880 - val_accuracy: 0.7362 - lr: 0.0010 - 5s/epoch - 25ms/step
# Epoch 26/100
# 215/215 - 5s - loss: 0.0261 - accuracy: 0.9886 - val_loss: 1.2159 - val_accuracy: 0.7323 - lr: 0.0010 - 5s/epoch - 25ms/step
# Epoch 27/100
# 215/215 - 5s - loss: 0.0256 - accuracy: 0.9879 - val_loss: 1.2298 - val_accuracy: 0.7310 - lr: 0.0010 - 5s/epoch - 24ms/step
# Epoch 28/100
# 215/215 - 4s - loss: 0.0254 - accuracy: 0.9879 - val_loss: 1.2622 - val_accuracy: 0.7375 - lr: 0.0010 - 4s/epoch - 18ms/step
# Epoch 29/100
# 215/215 - 5s - loss: 0.0244 - accuracy: 0.9902 - val_loss: 1.2897 - val_accuracy: 0.7297 - lr: 0.0010 - 5s/epoch - 22ms/step
# Epoch 30/100
# 215/215 - 4s - loss: 0.0238 - accuracy: 0.9898 - val_loss: 1.3202 - val_accuracy: 0.7178 - lr: 0.0010 - 4s/epoch - 20ms/step
# Epoch 31/100
# 215/215 - 5s - loss: 0.0246 - accuracy: 0.9892 - val_loss: 1.3098 - val_accuracy: 0.7310 - lr: 0.0010 - 5s/epoch - 25ms/step
# Epoch 32/100
# 215/215 - 5s - loss: 0.0235 - accuracy: 0.9891 - val_loss: 1.3286 - val_accuracy: 0.7310 - lr: 0.0010 - 5s/epoch - 23ms/step
# Epoch 33/100
# 215/215 - 7s - loss: 0.0234 - accuracy: 0.9880 - val_loss: 1.3574 - val_accuracy: 0.7283 - lr: 0.0010 - 7s/epoch - 32ms/step
# Epoch 34/100
# 215/215 - 5s - loss: 0.0235 - accuracy: 0.9882 - val_loss: 1.3817 - val_accuracy: 0.7362 - lr: 0.0010 - 5s/epoch - 26ms/step
# Epoch 35/100
# 215/215 - 6s - loss: 0.0224 - accuracy: 0.9889 - val_loss: 1.3852 - val_accuracy: 0.7336 - lr: 0.0010 - 6s/epoch - 26ms/step
# Epoch 36/100
# 215/215 - 9s - loss: 0.0228 - accuracy: 0.9895 - val_loss: 1.4357 - val_accuracy: 0.7178 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 37/100
# 215/215 - 6s - loss: 0.0231 - accuracy: 0.9883 - val_loss: 1.4095 - val_accuracy: 0.7310 - lr: 0.0010 - 6s/epoch - 30ms/step
# Epoch 38/100
# 215/215 - 6s - loss: 0.0224 - accuracy: 0.9888 - val_loss: 1.4478 - val_accuracy: 0.7310 - lr: 0.0010 - 6s/epoch - 28ms/step
# Epoch 39/100
# 215/215 - 4s - loss: 0.0222 - accuracy: 0.9893 - val_loss: 1.4338 - val_accuracy: 0.7297 - lr: 0.0010 - 4s/epoch - 21ms/step
# Epoch 40/100
# 215/215 - 5s - loss: 0.0221 - accuracy: 0.9886 - val_loss: 1.4660 - val_accuracy: 0.7244 - lr: 0.0010 - 5s/epoch - 21ms/step
# Epoch 41/100
# 215/215 - 4s - loss: 0.0215 - accuracy: 0.9883 - val_loss: 1.4842 - val_accuracy: 0.7310 - lr: 0.0010 - 4s/epoch - 21ms/step
# Epoch 42/100
# 215/215 - 6s - loss: 0.0216 - accuracy: 0.9892 - val_loss: 1.5006 - val_accuracy: 0.7231 - lr: 0.0010 - 6s/epoch - 28ms/step
# Epoch 43/100
# 215/215 - 9s - loss: 0.0212 - accuracy: 0.9886 - val_loss: 1.5075 - val_accuracy: 0.7297 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 44/100
# 215/215 - 6s - loss: 0.0215 - accuracy: 0.9893 - val_loss: 1.5216 - val_accuracy: 0.7192 - lr: 0.0010 - 6s/epoch - 29ms/step
# Epoch 45/100
# 215/215 - 5s - loss: 0.0209 - accuracy: 0.9898 - val_loss: 1.5490 - val_accuracy: 0.7073 - lr: 0.0010 - 5s/epoch - 22ms/step
# Epoch 46/100
# 215/215 - 5s - loss: 0.0203 - accuracy: 0.9899 - val_loss: 1.5435 - val_accuracy: 0.7270 - lr: 0.0010 - 5s/epoch - 24ms/step
# Epoch 47/100
# 215/215 - 7s - loss: 0.0213 - accuracy: 0.9883 - val_loss: 1.5479 - val_accuracy: 0.7165 - lr: 0.0010 - 7s/epoch - 34ms/step
# Epoch 48/100
# 215/215 - 8s - loss: 0.0202 - accuracy: 0.9888 - val_loss: 1.5749 - val_accuracy: 0.7139 - lr: 0.0010 - 8s/epoch - 36ms/step
# Epoch 49/100
# 215/215 - 6s - loss: 0.0207 - accuracy: 0.9896 - val_loss: 1.5916 - val_accuracy: 0.7087 - lr: 0.0010 - 6s/epoch - 27ms/step
# Epoch 50/100
# 215/215 - 6s - loss: 0.0202 - accuracy: 0.9891 - val_loss: 1.6195 - val_accuracy: 0.7192 - lr: 0.0010 - 6s/epoch - 27ms/step
# Epoch 51/100
# 215/215 - 5s - loss: 0.0205 - accuracy: 0.9886 - val_loss: 1.6108 - val_accuracy: 0.7192 - lr: 0.0010 - 5s/epoch - 23ms/step
# Epoch 52/100
# 215/215 - 5s - loss: 0.0204 - accuracy: 0.9892 - val_loss: 1.6244 - val_accuracy: 0.7192 - lr: 0.0010 - 5s/epoch - 24ms/step
# Epoch 53/100
# 215/215 - 5s - loss: 0.0203 - accuracy: 0.9886 - val_loss: 1.6775 - val_accuracy: 0.7047 - lr: 0.0010 - 5s/epoch - 21ms/step
# Epoch 54/100
# 215/215 - 5s - loss: 0.0199 - accuracy: 0.9895 - val_loss: 1.6361 - val_accuracy: 0.7087 - lr: 0.0010 - 5s/epoch - 22ms/step
# Epoch 55/100
# 215/215 - 5s - loss: 0.0199 - accuracy: 0.9895 - val_loss: 1.6348 - val_accuracy: 0.7244 - lr: 0.0010 - 5s/epoch - 25ms/step
# Epoch 56/100
# 215/215 - 4s - loss: 0.0205 - accuracy: 0.9898 - val_loss: 1.6500 - val_accuracy: 0.7178 - lr: 0.0010 - 4s/epoch - 19ms/step
# Epoch 57/100
# 215/215 - 6s - loss: 0.0200 - accuracy: 0.9893 - val_loss: 1.6834 - val_accuracy: 0.7152 - lr: 0.0010 - 6s/epoch - 26ms/step
# Epoch 58/100
# 215/215 - 5s - loss: 0.0199 - accuracy: 0.9898 - val_loss: 1.6685 - val_accuracy: 0.7060 - lr: 0.0010 - 5s/epoch - 25ms/step
# Epoch 59/100
# 215/215 - 5s - loss: 0.0198 - accuracy: 0.9892 - val_loss: 1.6843 - val_accuracy: 0.7073 - lr: 0.0010 - 5s/epoch - 23ms/step
# Epoch 60/100
# 215/215 - 5s - loss: 0.0196 - accuracy: 0.9896 - val_loss: 1.6892 - val_accuracy: 0.7192 - lr: 0.0010 - 5s/epoch - 23ms/step
# Epoch 61/100
# 215/215 - 5s - loss: 0.0188 - accuracy: 0.9896 - val_loss: 1.6989 - val_accuracy: 0.7165 - lr: 0.0010 - 5s/epoch - 22ms/step
# Epoch 62/100
# 215/215 - 4s - loss: 0.0189 - accuracy: 0.9899 - val_loss: 1.7073 - val_accuracy: 0.7113 - lr: 0.0010 - 4s/epoch - 20ms/step
# Epoch 63/100
# 215/215 - 4s - loss: 0.0187 - accuracy: 0.9904 - val_loss: 1.7182 - val_accuracy: 0.7021 - lr: 0.0010 - 4s/epoch - 21ms/step
# Epoch 64/100
# 215/215 - 8s - loss: 0.0193 - accuracy: 0.9901 - val_loss: 1.7330 - val_accuracy: 0.7047 - lr: 0.0010 - 8s/epoch - 35ms/step
# Epoch 65/100
# 215/215 - 5s - loss: 0.0187 - accuracy: 0.9898 - val_loss: 1.7120 - val_accuracy: 0.7139 - lr: 0.0010 - 5s/epoch - 24ms/step
# Epoch 66/100
# 215/215 - 4s - loss: 0.0187 - accuracy: 0.9898 - val_loss: 1.7329 - val_accuracy: 0.7047 - lr: 0.0010 - 4s/epoch - 20ms/step
# Epoch 67/100
# 215/215 - 6s - loss: 0.0192 - accuracy: 0.9898 - val_loss: 1.7166 - val_accuracy: 0.7113 - lr: 0.0010 - 6s/epoch - 27ms/step
# Epoch 68/100
# 215/215 - 7s - loss: 0.0187 - accuracy: 0.9901 - val_loss: 1.7462 - val_accuracy: 0.7087 - lr: 0.0010 - 7s/epoch - 35ms/step
# Epoch 69/100
# 215/215 - 6s - loss: 0.0187 - accuracy: 0.9908 - val_loss: 1.7369 - val_accuracy: 0.7100 - lr: 0.0010 - 6s/epoch - 26ms/step
# Epoch 70/100
# 215/215 - 6s - loss: 0.0181 - accuracy: 0.9907 - val_loss: 1.7580 - val_accuracy: 0.7047 - lr: 0.0010 - 6s/epoch - 27ms/step
# Epoch 71/100
# 215/215 - 4s - loss: 0.0187 - accuracy: 0.9895 - val_loss: 1.7480 - val_accuracy: 0.7113 - lr: 0.0010 - 4s/epoch - 19ms/step
# Epoch 72/100
# 215/215 - 5s - loss: 0.0186 - accuracy: 0.9896 - val_loss: 1.7641 - val_accuracy: 0.6969 - lr: 0.0010 - 5s/epoch - 24ms/step
# Epoch 73/100
# 215/215 - 5s - loss: 0.0186 - accuracy: 0.9901 - val_loss: 1.7528 - val_accuracy: 0.7073 - lr: 0.0010 - 5s/epoch - 25ms/step
# Epoch 74/100
# 215/215 - 5s - loss: 0.0182 - accuracy: 0.9902 - val_loss: 1.7681 - val_accuracy: 0.6969 - lr: 0.0010 - 5s/epoch - 25ms/step
# Epoch 75/100
# 215/215 - 4s - loss: 0.0180 - accuracy: 0.9905 - val_loss: 1.7700 - val_accuracy: 0.7060 - lr: 0.0010 - 4s/epoch - 19ms/step
# Epoch 76/100
# 215/215 - 4s - loss: 0.0183 - accuracy: 0.9886 - val_loss: 1.7602 - val_accuracy: 0.7100 - lr: 0.0010 - 4s/epoch - 20ms/step
# Epoch 77/100
# 215/215 - 5s - loss: 0.0180 - accuracy: 0.9885 - val_loss: 1.7810 - val_accuracy: 0.7073 - lr: 0.0010 - 5s/epoch - 22ms/step
# Epoch 78/100
# 215/215 - 5s - loss: 0.0186 - accuracy: 0.9896 - val_loss: 1.8008 - val_accuracy: 0.7021 - lr: 0.0010 - 5s/epoch - 22ms/step
# Epoch 79/100
# 215/215 - 6s - loss: 0.0180 - accuracy: 0.9905 - val_loss: 1.7609 - val_accuracy: 0.7021 - lr: 0.0010 - 6s/epoch - 28ms/step
# Epoch 80/100
# 215/215 - 5s - loss: 0.0185 - accuracy: 0.9891 - val_loss: 1.7698 - val_accuracy: 0.7060 - lr: 0.0010 - 5s/epoch - 21ms/step
# Epoch 81/100
# 215/215 - 5s - loss: 0.0179 - accuracy: 0.9905 - val_loss: 1.7707 - val_accuracy: 0.7021 - lr: 0.0010 - 5s/epoch - 21ms/step
# Epoch 82/100
# 215/215 - 4s - loss: 0.0180 - accuracy: 0.9892 - val_loss: 1.7823 - val_accuracy: 0.7047 - lr: 0.0010 - 4s/epoch - 21ms/step
# Epoch 83/100
# 215/215 - 5s - loss: 0.0179 - accuracy: 0.9904 - val_loss: 1.7735 - val_accuracy: 0.6982 - lr: 0.0010 - 5s/epoch - 21ms/step
# Epoch 84/100
# 215/215 - 5s - loss: 0.0177 - accuracy: 0.9898 - val_loss: 1.7747 - val_accuracy: 0.7008 - lr: 0.0010 - 5s/epoch - 23ms/step
# Epoch 85/100
# 215/215 - 7s - loss: 0.0175 - accuracy: 0.9905 - val_loss: 1.7631 - val_accuracy: 0.7073 - lr: 0.0010 - 7s/epoch - 32ms/step
# Epoch 86/100
# 215/215 - 4s - loss: 0.0177 - accuracy: 0.9898 - val_loss: 1.7865 - val_accuracy: 0.7021 - lr: 0.0010 - 4s/epoch - 20ms/step
# Epoch 87/100
# 215/215 - 5s - loss: 0.0176 - accuracy: 0.9892 - val_loss: 1.7710 - val_accuracy: 0.7060 - lr: 0.0010 - 5s/epoch - 25ms/step
# Epoch 88/100
# 215/215 - 5s - loss: 0.0175 - accuracy: 0.9899 - val_loss: 1.7837 - val_accuracy: 0.6955 - lr: 0.0010 - 5s/epoch - 25ms/step
# Epoch 89/100
# 215/215 - 6s - loss: 0.0176 - accuracy: 0.9904 - val_loss: 1.7776 - val_accuracy: 0.6995 - lr: 0.0010 - 6s/epoch - 26ms/step
# Epoch 90/100
# 215/215 - 7s - loss: 0.0175 - accuracy: 0.9908 - val_loss: 1.7788 - val_accuracy: 0.7034 - lr: 0.0010 - 7s/epoch - 33ms/step
# Epoch 91/100
# 215/215 - 10s - loss: 0.0175 - accuracy: 0.9905 - val_loss: 1.7747 - val_accuracy: 0.7100 - lr: 0.0010 - 10s/epoch - 47ms/step
# Epoch 92/100
# 215/215 - 7s - loss: 0.0175 - accuracy: 0.9893 - val_loss: 1.7837 - val_accuracy: 0.7060 - lr: 0.0010 - 7s/epoch - 31ms/step
# Epoch 93/100
# 215/215 - 6s - loss: 0.0175 - accuracy: 0.9893 - val_loss: 1.7810 - val_accuracy: 0.7034 - lr: 0.0010 - 6s/epoch - 26ms/step
# Epoch 94/100
# 215/215 - 5s - loss: 0.0173 - accuracy: 0.9902 - val_loss: 1.7984 - val_accuracy: 0.6969 - lr: 0.0010 - 5s/epoch - 21ms/step
# Epoch 95/100
# 215/215 - 4s - loss: 0.0177 - accuracy: 0.9901 - val_loss: 1.7782 - val_accuracy: 0.7047 - lr: 0.0010 - 4s/epoch - 19ms/step
# Epoch 96/100
# 215/215 - 4s - loss: 0.0175 - accuracy: 0.9895 - val_loss: 1.7722 - val_accuracy: 0.7034 - lr: 0.0010 - 4s/epoch - 19ms/step
# Epoch 97/100
# 215/215 - 5s - loss: 0.0170 - accuracy: 0.9895 - val_loss: 1.7858 - val_accuracy: 0.7021 - lr: 0.0010 - 5s/epoch - 22ms/step
# Epoch 98/100
# 215/215 - 6s - loss: 0.0173 - accuracy: 0.9898 - val_loss: 1.7825 - val_accuracy: 0.7060 - lr: 0.0010 - 6s/epoch - 26ms/step
# Epoch 99/100
# 215/215 - 7s - loss: 0.0173 - accuracy: 0.9898 - val_loss: 1.7782 - val_accuracy: 0.7060 - lr: 0.0010 - 7s/epoch - 32ms/step
# Epoch 100/100
# 215/215 - 5s - loss: 0.0171 - accuracy: 0.9904 - val_loss: 1.7860 - val_accuracy: 0.7060 - lr: 0.0010 - 5s/epoch - 23ms/step
# Reducing: binary_crossentropy for epochs: 100, num_iter: 0, model: lstm_model
# Epoch 1/100
# 215/215 - 14s - loss: 0.5131 - accuracy: 0.7469 - val_loss: 0.4659 - val_accuracy: 0.7940 - lr: 0.0010 - 14s/epoch - 63ms/step
# Epoch 2/100
# 215/215 - 7s - loss: 0.2950 - accuracy: 0.8786 - val_loss: 0.5408 - val_accuracy: 0.7822 - lr: 0.0010 - 7s/epoch - 35ms/step
# Epoch 3/100
# 215/215 - 7s - loss: 0.1795 - accuracy: 0.9339 - val_loss: 0.5562 - val_accuracy: 0.7638 - lr: 0.0010 - 7s/epoch - 32ms/step
# Epoch 4/100
# 215/215 - 7s - loss: 0.1073 - accuracy: 0.9620 - val_loss: 0.7413 - val_accuracy: 0.7520 - lr: 0.0010 - 7s/epoch - 32ms/step
# Epoch 5/100
# 215/215 - 7s - loss: 0.0704 - accuracy: 0.9750 - val_loss: 1.0172 - val_accuracy: 0.7664 - lr: 0.0010 - 7s/epoch - 33ms/step
# Epoch 6/100
# 215/215 - 8s - loss: 0.0459 - accuracy: 0.9815 - val_loss: 1.1903 - val_accuracy: 0.7362 - lr: 0.0010 - 8s/epoch - 36ms/step
# Epoch 7/100
# 215/215 - 7s - loss: 0.0372 - accuracy: 0.9844 - val_loss: 1.3444 - val_accuracy: 0.7375 - lr: 0.0010 - 7s/epoch - 34ms/step
# Epoch 8/100
# 215/215 - 7s - loss: 0.0341 - accuracy: 0.9857 - val_loss: 1.1829 - val_accuracy: 0.7270 - lr: 0.0010 - 7s/epoch - 30ms/step
# Epoch 9/100
# 215/215 - 9s - loss: 0.0330 - accuracy: 0.9855 - val_loss: 1.2495 - val_accuracy: 0.7402 - lr: 0.0010 - 9s/epoch - 42ms/step
# Epoch 10/100
# 215/215 - 7s - loss: 0.0310 - accuracy: 0.9863 - val_loss: 1.4294 - val_accuracy: 0.7244 - lr: 0.0010 - 7s/epoch - 34ms/step
# Epoch 11/100
# 215/215 - 9s - loss: 0.0214 - accuracy: 0.9893 - val_loss: 1.7075 - val_accuracy: 0.7100 - lr: 0.0010 - 9s/epoch - 44ms/step
# Epoch 12/100
# 215/215 - 9s - loss: 0.0214 - accuracy: 0.9892 - val_loss: 1.6472 - val_accuracy: 0.7283 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 13/100
# 215/215 - 7s - loss: 0.0236 - accuracy: 0.9899 - val_loss: 1.7444 - val_accuracy: 0.7087 - lr: 0.0010 - 7s/epoch - 31ms/step
# Epoch 14/100
# 215/215 - 8s - loss: 0.0240 - accuracy: 0.9891 - val_loss: 1.5572 - val_accuracy: 0.7087 - lr: 0.0010 - 8s/epoch - 38ms/step
# Epoch 15/100
# 215/215 - 11s - loss: 0.0267 - accuracy: 0.9877 - val_loss: 1.3216 - val_accuracy: 0.7493 - lr: 0.0010 - 11s/epoch - 51ms/step
# Epoch 16/100
# 215/215 - 8s - loss: 0.0233 - accuracy: 0.9885 - val_loss: 1.3542 - val_accuracy: 0.7060 - lr: 0.0010 - 8s/epoch - 35ms/step
# Epoch 17/100
# 215/215 - 11s - loss: 0.0207 - accuracy: 0.9898 - val_loss: 1.4799 - val_accuracy: 0.7336 - lr: 0.0010 - 11s/epoch - 50ms/step
# Epoch 18/100
# 215/215 - 9s - loss: 0.0162 - accuracy: 0.9911 - val_loss: 1.8174 - val_accuracy: 0.7375 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 19/100
# 215/215 - 8s - loss: 0.0155 - accuracy: 0.9917 - val_loss: 2.0186 - val_accuracy: 0.7310 - lr: 0.0010 - 8s/epoch - 35ms/step
# Epoch 20/100
# 215/215 - 7s - loss: 0.0233 - accuracy: 0.9892 - val_loss: 1.5891 - val_accuracy: 0.7402 - lr: 0.0010 - 7s/epoch - 32ms/step
# Epoch 21/100
# 215/215 - 8s - loss: 0.0212 - accuracy: 0.9893 - val_loss: 1.4046 - val_accuracy: 0.7480 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 22/100
# 215/215 - 7s - loss: 0.0173 - accuracy: 0.9898 - val_loss: 1.6376 - val_accuracy: 0.7546 - lr: 0.0010 - 7s/epoch - 34ms/step
# Epoch 23/100
# 215/215 - 7s - loss: 0.0172 - accuracy: 0.9911 - val_loss: 1.7428 - val_accuracy: 0.7336 - lr: 0.0010 - 7s/epoch - 34ms/step
# Epoch 24/100
# 215/215 - 7s - loss: 0.0161 - accuracy: 0.9914 - val_loss: 1.9113 - val_accuracy: 0.7283 - lr: 0.0010 - 7s/epoch - 31ms/step
# Epoch 25/100
# 215/215 - 10s - loss: 0.0140 - accuracy: 0.9917 - val_loss: 2.1246 - val_accuracy: 0.7218 - lr: 0.0010 - 10s/epoch - 44ms/step
# Epoch 26/100
# 215/215 - 8s - loss: 0.0196 - accuracy: 0.9908 - val_loss: 1.6827 - val_accuracy: 0.7126 - lr: 0.0010 - 8s/epoch - 36ms/step
# Epoch 27/100
# 215/215 - 8s - loss: 0.0216 - accuracy: 0.9888 - val_loss: 1.3895 - val_accuracy: 0.7493 - lr: 0.0010 - 8s/epoch - 38ms/step
# Epoch 28/100
# 215/215 - 9s - loss: 0.0216 - accuracy: 0.9883 - val_loss: 1.3616 - val_accuracy: 0.7441 - lr: 0.0010 - 9s/epoch - 42ms/step
# Epoch 29/100
# 215/215 - 9s - loss: 0.0189 - accuracy: 0.9896 - val_loss: 1.6267 - val_accuracy: 0.7375 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 30/100
# 215/215 - 8s - loss: 0.0152 - accuracy: 0.9918 - val_loss: 1.7818 - val_accuracy: 0.6864 - lr: 0.0010 - 8s/epoch - 38ms/step
# Epoch 31/100
# 215/215 - 10s - loss: 0.0198 - accuracy: 0.9904 - val_loss: 1.6712 - val_accuracy: 0.7441 - lr: 0.0010 - 10s/epoch - 46ms/step
# Epoch 32/100
# 215/215 - 8s - loss: 0.0159 - accuracy: 0.9915 - val_loss: 1.9041 - val_accuracy: 0.7362 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 33/100
# 215/215 - 8s - loss: 0.0147 - accuracy: 0.9915 - val_loss: 1.8466 - val_accuracy: 0.7336 - lr: 0.0010 - 8s/epoch - 36ms/step
# Epoch 34/100
# 215/215 - 8s - loss: 0.0137 - accuracy: 0.9918 - val_loss: 2.1117 - val_accuracy: 0.7323 - lr: 0.0010 - 8s/epoch - 36ms/step
# Epoch 35/100
# 215/215 - 8s - loss: 0.0144 - accuracy: 0.9918 - val_loss: 2.1522 - val_accuracy: 0.7165 - lr: 0.0010 - 8s/epoch - 38ms/step
# Epoch 36/100
# 215/215 - 7s - loss: 0.0184 - accuracy: 0.9908 - val_loss: 1.5455 - val_accuracy: 0.7297 - lr: 0.0010 - 7s/epoch - 33ms/step
# Epoch 37/100
# 215/215 - 6s - loss: 0.0154 - accuracy: 0.9917 - val_loss: 1.7513 - val_accuracy: 0.7349 - lr: 0.0010 - 6s/epoch - 30ms/step
# Epoch 38/100
# 215/215 - 8s - loss: 0.0143 - accuracy: 0.9918 - val_loss: 2.0625 - val_accuracy: 0.7192 - lr: 0.0010 - 8s/epoch - 36ms/step
# Epoch 39/100
# 215/215 - 11s - loss: 0.0146 - accuracy: 0.9915 - val_loss: 1.9903 - val_accuracy: 0.7349 - lr: 0.0010 - 11s/epoch - 51ms/step
# Epoch 40/100
# 215/215 - 10s - loss: 0.0136 - accuracy: 0.9915 - val_loss: 2.2181 - val_accuracy: 0.7231 - lr: 0.0010 - 10s/epoch - 45ms/step
# Epoch 41/100
# 215/215 - 9s - loss: 0.0158 - accuracy: 0.9917 - val_loss: 1.8813 - val_accuracy: 0.7178 - lr: 0.0010 - 9s/epoch - 42ms/step
# Epoch 42/100
# 215/215 - 9s - loss: 0.0149 - accuracy: 0.9920 - val_loss: 2.0216 - val_accuracy: 0.7336 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 43/100
# 215/215 - 8s - loss: 0.0193 - accuracy: 0.9895 - val_loss: 1.7913 - val_accuracy: 0.7402 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 44/100
# 215/215 - 10s - loss: 0.0208 - accuracy: 0.9898 - val_loss: 1.5125 - val_accuracy: 0.7336 - lr: 0.0010 - 10s/epoch - 46ms/step
# Epoch 45/100
# 215/215 - 7s - loss: 0.0163 - accuracy: 0.9908 - val_loss: 1.6375 - val_accuracy: 0.7244 - lr: 0.0010 - 7s/epoch - 32ms/step
# Epoch 46/100
# 215/215 - 7s - loss: 0.0152 - accuracy: 0.9918 - val_loss: 1.7515 - val_accuracy: 0.7323 - lr: 0.0010 - 7s/epoch - 32ms/step
# Epoch 47/100
# 215/215 - 8s - loss: 0.0137 - accuracy: 0.9904 - val_loss: 2.0052 - val_accuracy: 0.7415 - lr: 0.0010 - 8s/epoch - 36ms/step
# Epoch 48/100
# 215/215 - 8s - loss: 0.0130 - accuracy: 0.9923 - val_loss: 1.9721 - val_accuracy: 0.7336 - lr: 0.0010 - 8s/epoch - 36ms/step
# Epoch 49/100
# 215/215 - 7s - loss: 0.0144 - accuracy: 0.9917 - val_loss: 2.1287 - val_accuracy: 0.7349 - lr: 0.0010 - 7s/epoch - 30ms/step
# Epoch 50/100
# 215/215 - 7s - loss: 0.0148 - accuracy: 0.9918 - val_loss: 1.9390 - val_accuracy: 0.7402 - lr: 0.0010 - 7s/epoch - 34ms/step
# Epoch 51/100
# 215/215 - 8s - loss: 0.0144 - accuracy: 0.9920 - val_loss: 1.9325 - val_accuracy: 0.7336 - lr: 0.0010 - 8s/epoch - 35ms/step
# Epoch 52/100
# 215/215 - 6s - loss: 0.0135 - accuracy: 0.9918 - val_loss: 2.1499 - val_accuracy: 0.7402 - lr: 0.0010 - 6s/epoch - 28ms/step
# Epoch 53/100
# 215/215 - 6s - loss: 0.0133 - accuracy: 0.9921 - val_loss: 2.2841 - val_accuracy: 0.7362 - lr: 0.0010 - 6s/epoch - 28ms/step
# Epoch 54/100
# 215/215 - 6s - loss: 0.0131 - accuracy: 0.9920 - val_loss: 2.3458 - val_accuracy: 0.7375 - lr: 0.0010 - 6s/epoch - 28ms/step
# Epoch 55/100
# 215/215 - 8s - loss: 0.0130 - accuracy: 0.9915 - val_loss: 2.3942 - val_accuracy: 0.7336 - lr: 0.0010 - 8s/epoch - 36ms/step
# Epoch 56/100
# 215/215 - 8s - loss: 0.0144 - accuracy: 0.9918 - val_loss: 1.9456 - val_accuracy: 0.7388 - lr: 0.0010 - 8s/epoch - 35ms/step
# Epoch 57/100
# 215/215 - 7s - loss: 0.0175 - accuracy: 0.9908 - val_loss: 1.7897 - val_accuracy: 0.7362 - lr: 0.0010 - 7s/epoch - 31ms/step
# Epoch 58/100
# 215/215 - 8s - loss: 0.0147 - accuracy: 0.9915 - val_loss: 1.8735 - val_accuracy: 0.7467 - lr: 0.0010 - 8s/epoch - 37ms/step
# Epoch 59/100
# 215/215 - 8s - loss: 0.0180 - accuracy: 0.9910 - val_loss: 1.7951 - val_accuracy: 0.7270 - lr: 0.0010 - 8s/epoch - 35ms/step
# Epoch 60/100
# 215/215 - 7s - loss: 0.0150 - accuracy: 0.9912 - val_loss: 1.7951 - val_accuracy: 0.7428 - lr: 0.0010 - 7s/epoch - 31ms/step
# Epoch 61/100
# 215/215 - 7s - loss: 0.0131 - accuracy: 0.9921 - val_loss: 1.9128 - val_accuracy: 0.7467 - lr: 0.0010 - 7s/epoch - 31ms/step
# Epoch 62/100
# 215/215 - 7s - loss: 0.0129 - accuracy: 0.9915 - val_loss: 2.0088 - val_accuracy: 0.7467 - lr: 0.0010 - 7s/epoch - 31ms/step
# Epoch 63/100
# 215/215 - 7s - loss: 0.0156 - accuracy: 0.9912 - val_loss: 1.8390 - val_accuracy: 0.7283 - lr: 0.0010 - 7s/epoch - 31ms/step
# Epoch 64/100
# 215/215 - 7s - loss: 0.0137 - accuracy: 0.9918 - val_loss: 1.9659 - val_accuracy: 0.7126 - lr: 0.0010 - 7s/epoch - 32ms/step
# Epoch 65/100
# 215/215 - 6s - loss: 0.0132 - accuracy: 0.9923 - val_loss: 2.0426 - val_accuracy: 0.7297 - lr: 0.0010 - 6s/epoch - 30ms/step
# Epoch 66/100
# 215/215 - 6s - loss: 0.0130 - accuracy: 0.9920 - val_loss: 2.1063 - val_accuracy: 0.7165 - lr: 0.0010 - 6s/epoch - 28ms/step
# Epoch 67/100
# 215/215 - 7s - loss: 0.0131 - accuracy: 0.9920 - val_loss: 2.2959 - val_accuracy: 0.7231 - lr: 0.0010 - 7s/epoch - 31ms/step
# Epoch 68/100
# 215/215 - 6s - loss: 0.0126 - accuracy: 0.9918 - val_loss: 2.3316 - val_accuracy: 0.7297 - lr: 0.0010 - 6s/epoch - 28ms/step
# Epoch 69/100
# 215/215 - 7s - loss: 0.0129 - accuracy: 0.9918 - val_loss: 2.3951 - val_accuracy: 0.7349 - lr: 0.0010 - 7s/epoch - 31ms/step
# Epoch 70/100
# 215/215 - 9s - loss: 0.0126 - accuracy: 0.9914 - val_loss: 2.5026 - val_accuracy: 0.7244 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 71/100
# 215/215 - 6s - loss: 0.0129 - accuracy: 0.9917 - val_loss: 2.3209 - val_accuracy: 0.7297 - lr: 0.0010 - 6s/epoch - 30ms/step
# Epoch 72/100
# 215/215 - 7s - loss: 0.0125 - accuracy: 0.9917 - val_loss: 2.4261 - val_accuracy: 0.7297 - lr: 0.0010 - 7s/epoch - 31ms/step
# Epoch 73/100
# 215/215 - 6s - loss: 0.0127 - accuracy: 0.9917 - val_loss: 2.4795 - val_accuracy: 0.7192 - lr: 0.0010 - 6s/epoch - 30ms/step
# Epoch 74/100
# 215/215 - 7s - loss: 0.0139 - accuracy: 0.9912 - val_loss: 2.1510 - val_accuracy: 0.6982 - lr: 0.0010 - 7s/epoch - 33ms/step
# Epoch 75/100
# 215/215 - 7s - loss: 0.0163 - accuracy: 0.9910 - val_loss: 1.9368 - val_accuracy: 0.7205 - lr: 0.0010 - 7s/epoch - 33ms/step
# Epoch 76/100
# 215/215 - 7s - loss: 0.0149 - accuracy: 0.9910 - val_loss: 1.6873 - val_accuracy: 0.7165 - lr: 0.0010 - 7s/epoch - 32ms/step
# Epoch 77/100
# 215/215 - 7s - loss: 0.0136 - accuracy: 0.9914 - val_loss: 1.9478 - val_accuracy: 0.7336 - lr: 0.0010 - 7s/epoch - 32ms/step
# Epoch 78/100
# 215/215 - 6s - loss: 0.0130 - accuracy: 0.9921 - val_loss: 1.9078 - val_accuracy: 0.7231 - lr: 0.0010 - 6s/epoch - 29ms/step
# Epoch 79/100
# 215/215 - 6s - loss: 0.0126 - accuracy: 0.9915 - val_loss: 2.0062 - val_accuracy: 0.7336 - lr: 0.0010 - 6s/epoch - 29ms/step
# Epoch 80/100
# 215/215 - 7s - loss: 0.0128 - accuracy: 0.9921 - val_loss: 2.1170 - val_accuracy: 0.6916 - lr: 0.0010 - 7s/epoch - 35ms/step
# Epoch 81/100
# 215/215 - 6s - loss: 0.0137 - accuracy: 0.9924 - val_loss: 1.7490 - val_accuracy: 0.7349 - lr: 0.0010 - 6s/epoch - 29ms/step
# Epoch 82/100
# 215/215 - 6s - loss: 0.0132 - accuracy: 0.9923 - val_loss: 2.1419 - val_accuracy: 0.7349 - lr: 0.0010 - 6s/epoch - 29ms/step
# Epoch 83/100
# 215/215 - 8s - loss: 0.0127 - accuracy: 0.9923 - val_loss: 2.3033 - val_accuracy: 0.7283 - lr: 0.0010 - 8s/epoch - 38ms/step
# Epoch 84/100
# 215/215 - 7s - loss: 0.0125 - accuracy: 0.9921 - val_loss: 2.3018 - val_accuracy: 0.7297 - lr: 0.0010 - 7s/epoch - 31ms/step
# Epoch 85/100
# 215/215 - 7s - loss: 0.0125 - accuracy: 0.9920 - val_loss: 2.3308 - val_accuracy: 0.7297 - lr: 0.0010 - 7s/epoch - 31ms/step
# Epoch 86/100
# 215/215 - 6s - loss: 0.0125 - accuracy: 0.9915 - val_loss: 2.4064 - val_accuracy: 0.7270 - lr: 0.0010 - 6s/epoch - 29ms/step
# Epoch 87/100
# 215/215 - 7s - loss: 0.0124 - accuracy: 0.9926 - val_loss: 2.4014 - val_accuracy: 0.7283 - lr: 0.0010 - 7s/epoch - 32ms/step
# Epoch 88/100
# 215/215 - 8s - loss: 0.0125 - accuracy: 0.9923 - val_loss: 2.6595 - val_accuracy: 0.7152 - lr: 0.0010 - 8s/epoch - 38ms/step
# Epoch 89/100
# 215/215 - 7s - loss: 0.0135 - accuracy: 0.9914 - val_loss: 1.8844 - val_accuracy: 0.7402 - lr: 0.0010 - 7s/epoch - 30ms/step
# Epoch 90/100
# 215/215 - 7s - loss: 0.0187 - accuracy: 0.9901 - val_loss: 2.0672 - val_accuracy: 0.7283 - lr: 0.0010 - 7s/epoch - 31ms/step
# Epoch 91/100
# 215/215 - 8s - loss: 0.0155 - accuracy: 0.9918 - val_loss: 1.9429 - val_accuracy: 0.7244 - lr: 0.0010 - 8s/epoch - 36ms/step
# Epoch 92/100
# 215/215 - 6s - loss: 0.0138 - accuracy: 0.9915 - val_loss: 1.7339 - val_accuracy: 0.7323 - lr: 0.0010 - 6s/epoch - 29ms/step
# Epoch 93/100
# 215/215 - 6s - loss: 0.0138 - accuracy: 0.9918 - val_loss: 1.7740 - val_accuracy: 0.7192 - lr: 0.0010 - 6s/epoch - 29ms/step
# Epoch 94/100
# 215/215 - 7s - loss: 0.0127 - accuracy: 0.9927 - val_loss: 1.9954 - val_accuracy: 0.7218 - lr: 0.0010 - 7s/epoch - 30ms/step
# Epoch 95/100
# 215/215 - 6s - loss: 0.0125 - accuracy: 0.9915 - val_loss: 2.1331 - val_accuracy: 0.7218 - lr: 0.0010 - 6s/epoch - 29ms/step
# Epoch 96/100
# 215/215 - 7s - loss: 0.0125 - accuracy: 0.9917 - val_loss: 2.1948 - val_accuracy: 0.7231 - lr: 0.0010 - 7s/epoch - 33ms/step
# Epoch 97/100
# 215/215 - 7s - loss: 0.0124 - accuracy: 0.9920 - val_loss: 2.2787 - val_accuracy: 0.7218 - lr: 0.0010 - 7s/epoch - 31ms/step
# Epoch 98/100
# 215/215 - 6s - loss: 0.0124 - accuracy: 0.9920 - val_loss: 2.3500 - val_accuracy: 0.7218 - lr: 0.0010 - 6s/epoch - 29ms/step
# Epoch 99/100
# 215/215 - 8s - loss: 0.0124 - accuracy: 0.9918 - val_loss: 2.3535 - val_accuracy: 0.7257 - lr: 0.0010 - 8s/epoch - 35ms/step
# Epoch 100/100
# 215/215 - 7s - loss: 0.0124 - accuracy: 0.9924 - val_loss: 2.4500 - val_accuracy: 0.7244 - lr: 0.0010 - 7s/epoch - 32ms/step
# Reducing: binary_crossentropy for epochs: 100, num_iter: 0, model: bidirectional_lstm_model
# Epoch 1/100
# 215/215 - 14s - loss: 0.5085 - accuracy: 0.7498 - val_loss: 0.4634 - val_accuracy: 0.7979 - lr: 0.0010 - 14s/epoch - 65ms/step
# Epoch 2/100
# 215/215 - 8s - loss: 0.2909 - accuracy: 0.8819 - val_loss: 0.5146 - val_accuracy: 0.7848 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 3/100
# 215/215 - 9s - loss: 0.1699 - accuracy: 0.9365 - val_loss: 0.5890 - val_accuracy: 0.7717 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 4/100
# 215/215 - 9s - loss: 0.0974 - accuracy: 0.9677 - val_loss: 0.8612 - val_accuracy: 0.7598 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 5/100
# 215/215 - 8s - loss: 0.0678 - accuracy: 0.9756 - val_loss: 0.9023 - val_accuracy: 0.7717 - lr: 0.0010 - 8s/epoch - 38ms/step
# Epoch 6/100
# 215/215 - 8s - loss: 0.0499 - accuracy: 0.9809 - val_loss: 0.9985 - val_accuracy: 0.7362 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 7/100
# 215/215 - 9s - loss: 0.0325 - accuracy: 0.9882 - val_loss: 1.1251 - val_accuracy: 0.7388 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 8/100
# 215/215 - 8s - loss: 0.0255 - accuracy: 0.9880 - val_loss: 1.2816 - val_accuracy: 0.7546 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 9/100
# 215/215 - 8s - loss: 0.0253 - accuracy: 0.9886 - val_loss: 1.3986 - val_accuracy: 0.7257 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 10/100
# 215/215 - 8s - loss: 0.0234 - accuracy: 0.9885 - val_loss: 1.4961 - val_accuracy: 0.7572 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 11/100
# 215/215 - 8s - loss: 0.0215 - accuracy: 0.9891 - val_loss: 1.5284 - val_accuracy: 0.7375 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 12/100
# 215/215 - 9s - loss: 0.0201 - accuracy: 0.9895 - val_loss: 1.5670 - val_accuracy: 0.7428 - lr: 0.0010 - 9s/epoch - 43ms/step
# Epoch 13/100
# 215/215 - 10s - loss: 0.0178 - accuracy: 0.9898 - val_loss: 1.6646 - val_accuracy: 0.7402 - lr: 0.0010 - 10s/epoch - 47ms/step
# Epoch 14/100
# 215/215 - 9s - loss: 0.0172 - accuracy: 0.9895 - val_loss: 1.6867 - val_accuracy: 0.7520 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 15/100
# 215/215 - 9s - loss: 0.0168 - accuracy: 0.9907 - val_loss: 1.7345 - val_accuracy: 0.7428 - lr: 0.0010 - 9s/epoch - 43ms/step
# Epoch 16/100
# 215/215 - 8s - loss: 0.0159 - accuracy: 0.9907 - val_loss: 1.7097 - val_accuracy: 0.7375 - lr: 0.0010 - 8s/epoch - 38ms/step
# Epoch 17/100
# 215/215 - 9s - loss: 0.0164 - accuracy: 0.9901 - val_loss: 1.9641 - val_accuracy: 0.7047 - lr: 0.0010 - 9s/epoch - 43ms/step
# Epoch 18/100
# 215/215 - 9s - loss: 0.0410 - accuracy: 0.9841 - val_loss: 0.8653 - val_accuracy: 0.7480 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 19/100
# 215/215 - 9s - loss: 0.0454 - accuracy: 0.9794 - val_loss: 1.0526 - val_accuracy: 0.7559 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 20/100
# 215/215 - 9s - loss: 0.0276 - accuracy: 0.9873 - val_loss: 1.3597 - val_accuracy: 0.7441 - lr: 0.0010 - 9s/epoch - 43ms/step
# Epoch 21/100
# 215/215 - 8s - loss: 0.0182 - accuracy: 0.9895 - val_loss: 1.3564 - val_accuracy: 0.7625 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 22/100
# 215/215 - 9s - loss: 0.0169 - accuracy: 0.9901 - val_loss: 1.6161 - val_accuracy: 0.7480 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 23/100
# 215/215 - 9s - loss: 0.0158 - accuracy: 0.9908 - val_loss: 1.5951 - val_accuracy: 0.7507 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 24/100
# 215/215 - 8s - loss: 0.0157 - accuracy: 0.9904 - val_loss: 1.6511 - val_accuracy: 0.7402 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 25/100
# 215/215 - 9s - loss: 0.0152 - accuracy: 0.9905 - val_loss: 1.7048 - val_accuracy: 0.7218 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 26/100
# 215/215 - 8s - loss: 0.0154 - accuracy: 0.9905 - val_loss: 1.6342 - val_accuracy: 0.7585 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 27/100
# 215/215 - 10s - loss: 0.0149 - accuracy: 0.9902 - val_loss: 1.6828 - val_accuracy: 0.7428 - lr: 0.0010 - 10s/epoch - 46ms/step
# Epoch 28/100
# 215/215 - 10s - loss: 0.0153 - accuracy: 0.9905 - val_loss: 1.5428 - val_accuracy: 0.7625 - lr: 0.0010 - 10s/epoch - 45ms/step
# Epoch 29/100
# 215/215 - 8s - loss: 0.0158 - accuracy: 0.9901 - val_loss: 1.6799 - val_accuracy: 0.7349 - lr: 0.0010 - 8s/epoch - 38ms/step
# Epoch 30/100
# 215/215 - 9s - loss: 0.0189 - accuracy: 0.9902 - val_loss: 1.6042 - val_accuracy: 0.7480 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 31/100
# 215/215 - 8s - loss: 0.0217 - accuracy: 0.9889 - val_loss: 1.5146 - val_accuracy: 0.7388 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 32/100
# 215/215 - 9s - loss: 0.0193 - accuracy: 0.9892 - val_loss: 1.4668 - val_accuracy: 0.7375 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 33/100
# 215/215 - 9s - loss: 0.0188 - accuracy: 0.9912 - val_loss: 1.5591 - val_accuracy: 0.7362 - lr: 0.0010 - 9s/epoch - 42ms/step
# Epoch 34/100
# 215/215 - 9s - loss: 0.0179 - accuracy: 0.9910 - val_loss: 1.5595 - val_accuracy: 0.7362 - lr: 0.0010 - 9s/epoch - 43ms/step
# Epoch 35/100
# 215/215 - 9s - loss: 0.0201 - accuracy: 0.9902 - val_loss: 1.4647 - val_accuracy: 0.7441 - lr: 0.0010 - 9s/epoch - 43ms/step
# Epoch 36/100
# 215/215 - 9s - loss: 0.0174 - accuracy: 0.9901 - val_loss: 1.5517 - val_accuracy: 0.7362 - lr: 0.0010 - 9s/epoch - 42ms/step
# Epoch 37/100
# 215/215 - 9s - loss: 0.0159 - accuracy: 0.9905 - val_loss: 1.4616 - val_accuracy: 0.7375 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 38/100
# 215/215 - 9s - loss: 0.0156 - accuracy: 0.9898 - val_loss: 1.5098 - val_accuracy: 0.7388 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 39/100
# 215/215 - 9s - loss: 0.0145 - accuracy: 0.9907 - val_loss: 1.5212 - val_accuracy: 0.7388 - lr: 0.0010 - 9s/epoch - 43ms/step
# Epoch 40/100
# 215/215 - 9s - loss: 0.0145 - accuracy: 0.9898 - val_loss: 1.5673 - val_accuracy: 0.7270 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 41/100
# 215/215 - 10s - loss: 0.0143 - accuracy: 0.9912 - val_loss: 1.6096 - val_accuracy: 0.7283 - lr: 0.0010 - 10s/epoch - 47ms/step
# Epoch 42/100
# 215/215 - 9s - loss: 0.0141 - accuracy: 0.9908 - val_loss: 1.6369 - val_accuracy: 0.7270 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 43/100
# 215/215 - 10s - loss: 0.0141 - accuracy: 0.9908 - val_loss: 1.6350 - val_accuracy: 0.7244 - lr: 0.0010 - 10s/epoch - 45ms/step
# Epoch 44/100
# 215/215 - 9s - loss: 0.0142 - accuracy: 0.9911 - val_loss: 1.6555 - val_accuracy: 0.7152 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 45/100
# 215/215 - 10s - loss: 0.0141 - accuracy: 0.9908 - val_loss: 1.6417 - val_accuracy: 0.7178 - lr: 0.0010 - 10s/epoch - 45ms/step
# Epoch 46/100
# 215/215 - 9s - loss: 0.0149 - accuracy: 0.9914 - val_loss: 1.6668 - val_accuracy: 0.7165 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 47/100
# 215/215 - 8s - loss: 0.0160 - accuracy: 0.9905 - val_loss: 1.5631 - val_accuracy: 0.7297 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 48/100
# 215/215 - 9s - loss: 0.0156 - accuracy: 0.9905 - val_loss: 1.4924 - val_accuracy: 0.7402 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 49/100
# 215/215 - 9s - loss: 0.0139 - accuracy: 0.9911 - val_loss: 1.5670 - val_accuracy: 0.7283 - lr: 0.0010 - 9s/epoch - 43ms/step
# Epoch 50/100
# 215/215 - 10s - loss: 0.0149 - accuracy: 0.9907 - val_loss: 1.4170 - val_accuracy: 0.7283 - lr: 0.0010 - 10s/epoch - 46ms/step
# Epoch 51/100
# 215/215 - 10s - loss: 0.0161 - accuracy: 0.9904 - val_loss: 1.6431 - val_accuracy: 0.7244 - lr: 0.0010 - 10s/epoch - 45ms/step
# Epoch 52/100
# 215/215 - 9s - loss: 0.0166 - accuracy: 0.9907 - val_loss: 1.6176 - val_accuracy: 0.7283 - lr: 0.0010 - 9s/epoch - 42ms/step
# Epoch 53/100
# 215/215 - 9s - loss: 0.0140 - accuracy: 0.9914 - val_loss: 1.6046 - val_accuracy: 0.7205 - lr: 0.0010 - 9s/epoch - 43ms/step
# Epoch 54/100
# 215/215 - 10s - loss: 0.0137 - accuracy: 0.9915 - val_loss: 1.6083 - val_accuracy: 0.7283 - lr: 0.0010 - 10s/epoch - 44ms/step
# Epoch 55/100
# 215/215 - 10s - loss: 0.0135 - accuracy: 0.9914 - val_loss: 1.6247 - val_accuracy: 0.7218 - lr: 0.0010 - 10s/epoch - 47ms/step
# Epoch 56/100
# 215/215 - 9s - loss: 0.0135 - accuracy: 0.9911 - val_loss: 1.6371 - val_accuracy: 0.7297 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 57/100
# 215/215 - 9s - loss: 0.0136 - accuracy: 0.9912 - val_loss: 1.6665 - val_accuracy: 0.7244 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 58/100
# 215/215 - 9s - loss: 0.0134 - accuracy: 0.9915 - val_loss: 1.6602 - val_accuracy: 0.7100 - lr: 0.0010 - 9s/epoch - 42ms/step
# Epoch 59/100
# 215/215 - 8s - loss: 0.0133 - accuracy: 0.9914 - val_loss: 1.6605 - val_accuracy: 0.7270 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 60/100
# 215/215 - 8s - loss: 0.0135 - accuracy: 0.9918 - val_loss: 1.8230 - val_accuracy: 0.7231 - lr: 0.0010 - 8s/epoch - 38ms/step
# Epoch 61/100
# 215/215 - 9s - loss: 0.0133 - accuracy: 0.9918 - val_loss: 1.8316 - val_accuracy: 0.7283 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 62/100
# 215/215 - 9s - loss: 0.0149 - accuracy: 0.9904 - val_loss: 1.7207 - val_accuracy: 0.7257 - lr: 0.0010 - 9s/epoch - 43ms/step
# Epoch 63/100
# 215/215 - 8s - loss: 0.0177 - accuracy: 0.9914 - val_loss: 1.7249 - val_accuracy: 0.7087 - lr: 0.0010 - 8s/epoch - 38ms/step
# Epoch 64/100
# 215/215 - 9s - loss: 0.0166 - accuracy: 0.9920 - val_loss: 1.6206 - val_accuracy: 0.7139 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 65/100
# 215/215 - 9s - loss: 0.0167 - accuracy: 0.9905 - val_loss: 1.4795 - val_accuracy: 0.7244 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 66/100
# 215/215 - 8s - loss: 0.0176 - accuracy: 0.9910 - val_loss: 1.4555 - val_accuracy: 0.7152 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 67/100
# 215/215 - 9s - loss: 0.0150 - accuracy: 0.9908 - val_loss: 1.4870 - val_accuracy: 0.7218 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 68/100
# 215/215 - 10s - loss: 0.0130 - accuracy: 0.9921 - val_loss: 1.6241 - val_accuracy: 0.7152 - lr: 0.0010 - 10s/epoch - 46ms/step
# Epoch 69/100
# 215/215 - 10s - loss: 0.0131 - accuracy: 0.9921 - val_loss: 1.6006 - val_accuracy: 0.7218 - lr: 0.0010 - 10s/epoch - 47ms/step
# Epoch 70/100
# 215/215 - 8s - loss: 0.0129 - accuracy: 0.9915 - val_loss: 1.6490 - val_accuracy: 0.7178 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 71/100
# 215/215 - 9s - loss: 0.0128 - accuracy: 0.9915 - val_loss: 1.6779 - val_accuracy: 0.7231 - lr: 0.0010 - 9s/epoch - 43ms/step
# Epoch 72/100
# 215/215 - 9s - loss: 0.0128 - accuracy: 0.9926 - val_loss: 1.6795 - val_accuracy: 0.7152 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 73/100
# 215/215 - 8s - loss: 0.0129 - accuracy: 0.9911 - val_loss: 1.6902 - val_accuracy: 0.7218 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 74/100
# 215/215 - 8s - loss: 0.0129 - accuracy: 0.9911 - val_loss: 1.7501 - val_accuracy: 0.7126 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 75/100
# 215/215 - 8s - loss: 0.0129 - accuracy: 0.9914 - val_loss: 1.6834 - val_accuracy: 0.7205 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 76/100
# 215/215 - 8s - loss: 0.0130 - accuracy: 0.9914 - val_loss: 1.8471 - val_accuracy: 0.7021 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 77/100
# 215/215 - 9s - loss: 0.0128 - accuracy: 0.9912 - val_loss: 1.6970 - val_accuracy: 0.7087 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 78/100
# 215/215 - 8s - loss: 0.0128 - accuracy: 0.9917 - val_loss: 1.7172 - val_accuracy: 0.7152 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 79/100
# 215/215 - 9s - loss: 0.0128 - accuracy: 0.9921 - val_loss: 1.7017 - val_accuracy: 0.7231 - lr: 0.0010 - 9s/epoch - 43ms/step
# Epoch 80/100
# 215/215 - 9s - loss: 0.0128 - accuracy: 0.9914 - val_loss: 1.7911 - val_accuracy: 0.7139 - lr: 0.0010 - 9s/epoch - 42ms/step
# Epoch 81/100
# 215/215 - 9s - loss: 0.0128 - accuracy: 0.9917 - val_loss: 1.7448 - val_accuracy: 0.7192 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 82/100
# 215/215 - 9s - loss: 0.0138 - accuracy: 0.9911 - val_loss: 1.5451 - val_accuracy: 0.7178 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 83/100
# 215/215 - 9s - loss: 0.0141 - accuracy: 0.9908 - val_loss: 1.6655 - val_accuracy: 0.7113 - lr: 0.0010 - 9s/epoch - 43ms/step
# Epoch 84/100
# 215/215 - 10s - loss: 0.0130 - accuracy: 0.9917 - val_loss: 1.8159 - val_accuracy: 0.7113 - lr: 0.0010 - 10s/epoch - 45ms/step
# Epoch 85/100
# 215/215 - 8s - loss: 0.0141 - accuracy: 0.9923 - val_loss: 1.7742 - val_accuracy: 0.7126 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 86/100
# 215/215 - 8s - loss: 0.0145 - accuracy: 0.9907 - val_loss: 1.7241 - val_accuracy: 0.7297 - lr: 0.0010 - 8s/epoch - 38ms/step
# Epoch 87/100
# 215/215 - 9s - loss: 0.0148 - accuracy: 0.9911 - val_loss: 1.7191 - val_accuracy: 0.7205 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 88/100
# 215/215 - 8s - loss: 0.0130 - accuracy: 0.9918 - val_loss: 1.8018 - val_accuracy: 0.7021 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 89/100
# 215/215 - 8s - loss: 0.0129 - accuracy: 0.9917 - val_loss: 1.8268 - val_accuracy: 0.7192 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 90/100
# 215/215 - 9s - loss: 0.0129 - accuracy: 0.9920 - val_loss: 1.8496 - val_accuracy: 0.6995 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 91/100
# 215/215 - 8s - loss: 0.0128 - accuracy: 0.9917 - val_loss: 1.9017 - val_accuracy: 0.6903 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 92/100
# 215/215 - 9s - loss: 0.0127 - accuracy: 0.9912 - val_loss: 1.9226 - val_accuracy: 0.6916 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 93/100
# 215/215 - 9s - loss: 0.0126 - accuracy: 0.9915 - val_loss: 1.9158 - val_accuracy: 0.6995 - lr: 0.0010 - 9s/epoch - 43ms/step
# Epoch 94/100
# 215/215 - 9s - loss: 0.0126 - accuracy: 0.9923 - val_loss: 1.9243 - val_accuracy: 0.7008 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 95/100
# 215/215 - 10s - loss: 0.0127 - accuracy: 0.9915 - val_loss: 1.9134 - val_accuracy: 0.7073 - lr: 0.0010 - 10s/epoch - 46ms/step
# Epoch 96/100
# 215/215 - 8s - loss: 0.0127 - accuracy: 0.9917 - val_loss: 1.9479 - val_accuracy: 0.6969 - lr: 0.0010 - 8s/epoch - 38ms/step
# Epoch 97/100
# 215/215 - 8s - loss: 0.0126 - accuracy: 0.9917 - val_loss: 1.9251 - val_accuracy: 0.7034 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 98/100
# 215/215 - 9s - loss: 0.0127 - accuracy: 0.9918 - val_loss: 1.9391 - val_accuracy: 0.7008 - lr: 0.0010 - 9s/epoch - 43ms/step
# Epoch 99/100
# 215/215 - 9s - loss: 0.0138 - accuracy: 0.9918 - val_loss: 1.8720 - val_accuracy: 0.7060 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 100/100
# 215/215 - 10s - loss: 0.0144 - accuracy: 0.9918 - val_loss: 1.8407 - val_accuracy: 0.7126 - lr: 0.0010 - 10s/epoch - 45ms/step
# Reducing: binary_crossentropy for epochs: 100, num_iter: 1, model: dense_model
# Epoch 1/100
# 215/215 - 6s - loss: 0.0181 - accuracy: 0.9910 - val_loss: 1.7795 - val_accuracy: 0.7021 - lr: 0.0010 - 6s/epoch - 30ms/step
# Epoch 2/100
# 215/215 - 5s - loss: 0.0171 - accuracy: 0.9911 - val_loss: 1.7647 - val_accuracy: 0.7021 - lr: 0.0010 - 5s/epoch - 24ms/step
# Epoch 3/100
# 215/215 - 5s - loss: 0.0171 - accuracy: 0.9902 - val_loss: 1.8003 - val_accuracy: 0.6850 - lr: 0.0010 - 5s/epoch - 24ms/step
# Epoch 4/100
# 215/215 - 5s - loss: 0.0175 - accuracy: 0.9898 - val_loss: 1.7644 - val_accuracy: 0.7034 - lr: 0.0010 - 5s/epoch - 21ms/step
# Epoch 5/100
# 215/215 - 5s - loss: 0.0170 - accuracy: 0.9905 - val_loss: 1.7709 - val_accuracy: 0.7047 - lr: 0.0010 - 5s/epoch - 22ms/step
# Epoch 6/100
# 215/215 - 4s - loss: 0.0175 - accuracy: 0.9892 - val_loss: 1.7825 - val_accuracy: 0.6969 - lr: 0.0010 - 4s/epoch - 21ms/step
# Epoch 7/100
# 215/215 - 5s - loss: 0.0169 - accuracy: 0.9901 - val_loss: 1.7730 - val_accuracy: 0.7034 - lr: 0.0010 - 5s/epoch - 22ms/step
# Epoch 8/100
# 215/215 - 5s - loss: 0.0168 - accuracy: 0.9911 - val_loss: 1.7864 - val_accuracy: 0.6942 - lr: 0.0010 - 5s/epoch - 22ms/step
# Epoch 9/100
# 215/215 - 5s - loss: 0.0171 - accuracy: 0.9898 - val_loss: 1.7799 - val_accuracy: 0.6982 - lr: 0.0010 - 5s/epoch - 25ms/step
# Epoch 10/100
# 215/215 - 5s - loss: 0.0170 - accuracy: 0.9905 - val_loss: 1.7710 - val_accuracy: 0.7034 - lr: 0.0010 - 5s/epoch - 25ms/step
# Epoch 11/100
# 215/215 - 4s - loss: 0.0166 - accuracy: 0.9902 - val_loss: 1.7754 - val_accuracy: 0.6995 - lr: 0.0010 - 4s/epoch - 21ms/step
# Epoch 12/100
# 215/215 - 5s - loss: 0.0168 - accuracy: 0.9910 - val_loss: 1.7934 - val_accuracy: 0.6982 - lr: 0.0010 - 5s/epoch - 22ms/step
# Epoch 13/100
# 215/215 - 5s - loss: 0.0168 - accuracy: 0.9902 - val_loss: 1.8030 - val_accuracy: 0.6982 - lr: 0.0010 - 5s/epoch - 25ms/step
# Epoch 14/100
# 215/215 - 6s - loss: 0.0166 - accuracy: 0.9895 - val_loss: 1.8011 - val_accuracy: 0.6969 - lr: 0.0010 - 6s/epoch - 28ms/step
# Epoch 15/100
# 215/215 - 4s - loss: 0.0167 - accuracy: 0.9904 - val_loss: 1.7955 - val_accuracy: 0.7021 - lr: 0.0010 - 4s/epoch - 21ms/step
# Epoch 16/100
# 215/215 - 6s - loss: 0.0165 - accuracy: 0.9907 - val_loss: 1.7927 - val_accuracy: 0.7087 - lr: 0.0010 - 6s/epoch - 30ms/step
# Epoch 17/100
# 215/215 - 5s - loss: 0.0170 - accuracy: 0.9904 - val_loss: 1.7925 - val_accuracy: 0.7047 - lr: 0.0010 - 5s/epoch - 24ms/step
# Epoch 18/100
# 215/215 - 5s - loss: 0.0165 - accuracy: 0.9904 - val_loss: 1.7934 - val_accuracy: 0.7073 - lr: 0.0010 - 5s/epoch - 23ms/step
# Epoch 19/100
# 215/215 - 6s - loss: 0.0166 - accuracy: 0.9902 - val_loss: 1.7971 - val_accuracy: 0.7087 - lr: 0.0010 - 6s/epoch - 26ms/step
# Epoch 20/100
# 215/215 - 6s - loss: 0.0167 - accuracy: 0.9902 - val_loss: 1.8020 - val_accuracy: 0.7034 - lr: 0.0010 - 6s/epoch - 27ms/step
# Epoch 21/100
# 215/215 - 5s - loss: 0.0166 - accuracy: 0.9901 - val_loss: 1.7929 - val_accuracy: 0.7087 - lr: 0.0010 - 5s/epoch - 22ms/step
# Epoch 22/100
# 215/215 - 4s - loss: 0.0166 - accuracy: 0.9902 - val_loss: 1.8083 - val_accuracy: 0.7034 - lr: 0.0010 - 4s/epoch - 20ms/step
# Epoch 23/100
# 215/215 - 5s - loss: 0.0165 - accuracy: 0.9898 - val_loss: 1.7895 - val_accuracy: 0.7126 - lr: 0.0010 - 5s/epoch - 21ms/step
# Epoch 24/100
# 215/215 - 5s - loss: 0.0168 - accuracy: 0.9895 - val_loss: 1.7963 - val_accuracy: 0.7034 - lr: 0.0010 - 5s/epoch - 23ms/step
# Epoch 25/100
# 215/215 - 5s - loss: 0.0166 - accuracy: 0.9902 - val_loss: 1.8101 - val_accuracy: 0.6982 - lr: 0.0010 - 5s/epoch - 25ms/step
# Epoch 26/100
# 215/215 - 6s - loss: 0.0166 - accuracy: 0.9904 - val_loss: 1.8082 - val_accuracy: 0.7113 - lr: 0.0010 - 6s/epoch - 26ms/step
# Epoch 27/100
# 215/215 - 5s - loss: 0.0164 - accuracy: 0.9892 - val_loss: 1.8133 - val_accuracy: 0.7113 - lr: 0.0010 - 5s/epoch - 23ms/step
# Epoch 28/100
# 215/215 - 5s - loss: 0.0166 - accuracy: 0.9895 - val_loss: 1.8091 - val_accuracy: 0.7100 - lr: 0.0010 - 5s/epoch - 24ms/step
# Epoch 29/100
# 215/215 - 5s - loss: 0.0165 - accuracy: 0.9911 - val_loss: 1.8138 - val_accuracy: 0.7021 - lr: 0.0010 - 5s/epoch - 24ms/step
# Epoch 30/100
# 215/215 - 4s - loss: 0.0164 - accuracy: 0.9914 - val_loss: 1.8270 - val_accuracy: 0.6982 - lr: 0.0010 - 4s/epoch - 21ms/step
# Epoch 31/100
# 215/215 - 5s - loss: 0.0166 - accuracy: 0.9901 - val_loss: 1.8096 - val_accuracy: 0.6995 - lr: 0.0010 - 5s/epoch - 26ms/step
# Epoch 32/100
# 215/215 - 5s - loss: 0.0162 - accuracy: 0.9907 - val_loss: 1.8076 - val_accuracy: 0.7100 - lr: 0.0010 - 5s/epoch - 21ms/step
# Epoch 33/100
# 215/215 - 5s - loss: 0.0164 - accuracy: 0.9904 - val_loss: 1.8150 - val_accuracy: 0.7073 - lr: 0.0010 - 5s/epoch - 21ms/step
# Epoch 34/100
# 215/215 - 5s - loss: 0.0164 - accuracy: 0.9907 - val_loss: 1.8218 - val_accuracy: 0.7113 - lr: 0.0010 - 5s/epoch - 22ms/step
# Epoch 35/100
# 215/215 - 5s - loss: 0.0163 - accuracy: 0.9896 - val_loss: 1.8196 - val_accuracy: 0.7126 - lr: 0.0010 - 5s/epoch - 23ms/step
# Epoch 36/100
# 215/215 - 4s - loss: 0.0164 - accuracy: 0.9912 - val_loss: 1.8294 - val_accuracy: 0.7021 - lr: 0.0010 - 4s/epoch - 20ms/step
# Epoch 37/100
# 215/215 - 4s - loss: 0.0163 - accuracy: 0.9908 - val_loss: 1.8063 - val_accuracy: 0.7034 - lr: 0.0010 - 4s/epoch - 21ms/step
# Epoch 38/100
# 215/215 - 5s - loss: 0.0162 - accuracy: 0.9908 - val_loss: 1.8165 - val_accuracy: 0.7126 - lr: 0.0010 - 5s/epoch - 24ms/step
# Epoch 39/100
# 215/215 - 6s - loss: 0.0164 - accuracy: 0.9908 - val_loss: 1.8073 - val_accuracy: 0.7100 - lr: 0.0010 - 6s/epoch - 26ms/step
# Epoch 40/100
# 215/215 - 6s - loss: 0.0162 - accuracy: 0.9895 - val_loss: 1.8170 - val_accuracy: 0.7113 - lr: 0.0010 - 6s/epoch - 29ms/step
# Epoch 41/100
# 215/215 - 6s - loss: 0.0162 - accuracy: 0.9902 - val_loss: 1.8240 - val_accuracy: 0.7034 - lr: 0.0010 - 6s/epoch - 26ms/step
# Epoch 42/100
# 215/215 - 4s - loss: 0.0161 - accuracy: 0.9904 - val_loss: 1.8386 - val_accuracy: 0.7087 - lr: 0.0010 - 4s/epoch - 20ms/step
# Epoch 43/100
# 215/215 - 6s - loss: 0.0162 - accuracy: 0.9893 - val_loss: 1.8330 - val_accuracy: 0.7047 - lr: 0.0010 - 6s/epoch - 27ms/step
# Epoch 44/100
# 215/215 - 6s - loss: 0.0162 - accuracy: 0.9910 - val_loss: 1.8379 - val_accuracy: 0.7060 - lr: 0.0010 - 6s/epoch - 28ms/step
# Epoch 45/100
# 215/215 - 6s - loss: 0.0161 - accuracy: 0.9910 - val_loss: 1.8416 - val_accuracy: 0.6982 - lr: 0.0010 - 6s/epoch - 26ms/step
# Epoch 46/100
# ...
# Epoch 35/100
# 215/215 - 8s - loss: 0.0123 - accuracy: 0.9920 - val_loss: 1.6899 - val_accuracy: 0.7218 - lr: 0.0010 - 8s/epoch - 38ms/step
# Epoch 36/100
# 215/215 - 8s - loss: 0.0123 - accuracy: 0.9924 - val_loss: 1.7148 - val_accuracy: 0.7192 - lr: 0.0010 - 8s/epoch - 37ms/step
# Epoch 37/100
# 215/215 - 8s - loss: 0.0125 - accuracy: 0.9915 - val_loss: 1.7496 - val_accuracy: 0.7165 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 38/100
# 215/215 - 8s - loss: 0.0123 - accuracy: 0.9914 - val_loss: 1.7640 - val_accuracy: 0.7165 - lr: 0.0010 - 8s/epoch - 40ms/step
# Epoch 39/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9912 - val_loss: 1.7806 - val_accuracy: 0.7113 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 40/100
# 215/215 - 8s - loss: 0.0122 - accuracy: 0.9907 - val_loss: 1.8022 - val_accuracy: 0.7126 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 41/100
# 215/215 - 9s - loss: 0.0123 - accuracy: 0.9917 - val_loss: 1.8243 - val_accuracy: 0.7152 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 42/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9915 - val_loss: 1.8446 - val_accuracy: 0.7139 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 43/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9921 - val_loss: 1.8563 - val_accuracy: 0.7165 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 44/100
# 215/215 - 9s - loss: 0.0123 - accuracy: 0.9917 - val_loss: 1.8769 - val_accuracy: 0.7126 - lr: 0.0010 - 9s/epoch - 42ms/step
# Epoch 45/100
# 215/215 - 8s - loss: 0.0122 - accuracy: 0.9915 - val_loss: 1.8886 - val_accuracy: 0.7087 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 46/100
# 215/215 - 8s - loss: 0.0123 - accuracy: 0.9911 - val_loss: 1.9019 - val_accuracy: 0.7126 - lr: 0.0010 - 8s/epoch - 36ms/step
# Epoch 47/100
# 215/215 - 10s - loss: 0.0122 - accuracy: 0.9910 - val_loss: 1.9123 - val_accuracy: 0.7152 - lr: 0.0010 - 10s/epoch - 48ms/step
# Epoch 48/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9917 - val_loss: 1.9169 - val_accuracy: 0.7192 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 49/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9915 - val_loss: 1.9289 - val_accuracy: 0.7152 - lr: 0.0010 - 9s/epoch - 43ms/step
# Epoch 50/100
# 215/215 - 8s - loss: 0.0123 - accuracy: 0.9914 - val_loss: 1.9367 - val_accuracy: 0.7139 - lr: 0.0010 - 8s/epoch - 36ms/step
# Epoch 51/100
# 215/215 - 8s - loss: 0.0123 - accuracy: 0.9908 - val_loss: 1.9591 - val_accuracy: 0.7152 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 52/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9917 - val_loss: 1.9599 - val_accuracy: 0.7205 - lr: 0.0010 - 9s/epoch - 43ms/step
# Epoch 53/100
# 215/215 - 8s - loss: 0.0122 - accuracy: 0.9912 - val_loss: 1.9561 - val_accuracy: 0.7192 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 54/100
# 215/215 - 9s - loss: 0.0123 - accuracy: 0.9918 - val_loss: 1.9704 - val_accuracy: 0.7178 - lr: 0.0010 - 9s/epoch - 42ms/step
# Epoch 55/100
# 215/215 - 9s - loss: 0.0123 - accuracy: 0.9914 - val_loss: 1.9875 - val_accuracy: 0.7126 - lr: 0.0010 - 9s/epoch - 42ms/step
# Epoch 56/100
# 215/215 - 8s - loss: 0.0123 - accuracy: 0.9915 - val_loss: 1.9829 - val_accuracy: 0.7113 - lr: 0.0010 - 8s/epoch - 38ms/step
# Epoch 57/100
# 215/215 - 8s - loss: 0.0122 - accuracy: 0.9915 - val_loss: 1.9926 - val_accuracy: 0.7165 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 58/100
# 215/215 - 8s - loss: 0.0123 - accuracy: 0.9915 - val_loss: 2.0055 - val_accuracy: 0.7113 - lr: 0.0010 - 8s/epoch - 37ms/step
# Epoch 59/100
# 215/215 - 10s - loss: 0.0123 - accuracy: 0.9921 - val_loss: 2.0337 - val_accuracy: 0.7008 - lr: 0.0010 - 10s/epoch - 46ms/step
# Epoch 60/100
# 215/215 - 10s - loss: 0.0122 - accuracy: 0.9923 - val_loss: 2.0430 - val_accuracy: 0.7139 - lr: 0.0010 - 10s/epoch - 47ms/step
# Epoch 61/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9918 - val_loss: 2.0283 - val_accuracy: 0.7152 - lr: 0.0010 - 9s/epoch - 43ms/step
# Epoch 62/100
# 215/215 - 8s - loss: 0.0123 - accuracy: 0.9918 - val_loss: 2.0436 - val_accuracy: 0.7139 - lr: 0.0010 - 8s/epoch - 38ms/step
# Epoch 63/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9921 - val_loss: 2.0694 - val_accuracy: 0.7087 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 64/100
# 215/215 - 9s - loss: 0.0126 - accuracy: 0.9924 - val_loss: 2.0751 - val_accuracy: 0.7060 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 65/100
# 215/215 - 9s - loss: 0.0127 - accuracy: 0.9918 - val_loss: 1.9298 - val_accuracy: 0.7283 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 66/100
# 215/215 - 8s - loss: 0.0151 - accuracy: 0.9917 - val_loss: 1.7977 - val_accuracy: 0.6955 - lr: 0.0010 - 8s/epoch - 38ms/step
# Epoch 67/100
# 215/215 - 8s - loss: 0.0190 - accuracy: 0.9899 - val_loss: 1.7214 - val_accuracy: 0.7113 - lr: 0.0010 - 8s/epoch - 38ms/step
# Epoch 68/100
# 215/215 - 9s - loss: 0.0125 - accuracy: 0.9926 - val_loss: 1.7669 - val_accuracy: 0.7165 - lr: 0.0010 - 9s/epoch - 42ms/step
# Epoch 69/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9921 - val_loss: 1.7717 - val_accuracy: 0.7165 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 70/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9917 - val_loss: 1.8145 - val_accuracy: 0.7165 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 71/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9914 - val_loss: 1.8399 - val_accuracy: 0.7178 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 72/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9927 - val_loss: 1.8589 - val_accuracy: 0.7152 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 73/100
# 215/215 - 8s - loss: 0.0122 - accuracy: 0.9915 - val_loss: 1.8762 - val_accuracy: 0.7152 - lr: 0.0010 - 8s/epoch - 38ms/step
# Epoch 74/100
# 215/215 - 10s - loss: 0.0122 - accuracy: 0.9914 - val_loss: 1.8925 - val_accuracy: 0.7165 - lr: 0.0010 - 10s/epoch - 49ms/step
# Epoch 75/100
# 215/215 - 8s - loss: 0.0122 - accuracy: 0.9912 - val_loss: 1.8905 - val_accuracy: 0.7178 - lr: 0.0010 - 8s/epoch - 38ms/step
# Epoch 76/100
# 215/215 - 8s - loss: 0.0122 - accuracy: 0.9917 - val_loss: 1.9429 - val_accuracy: 0.7139 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 77/100
# 215/215 - 9s - loss: 0.0121 - accuracy: 0.9924 - val_loss: 1.9296 - val_accuracy: 0.7113 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 78/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9920 - val_loss: 1.9345 - val_accuracy: 0.7126 - lr: 0.0010 - 9s/epoch - 42ms/step
# Epoch 79/100
# 215/215 - 8s - loss: 0.0121 - accuracy: 0.9921 - val_loss: 1.9597 - val_accuracy: 0.7139 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 80/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9917 - val_loss: 1.9818 - val_accuracy: 0.7139 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 81/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9921 - val_loss: 1.9733 - val_accuracy: 0.7178 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 82/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9911 - val_loss: 1.9822 - val_accuracy: 0.7152 - lr: 0.0010 - 9s/epoch - 44ms/step
# Epoch 83/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9920 - val_loss: 1.9963 - val_accuracy: 0.7139 - lr: 0.0010 - 9s/epoch - 43ms/step
# Epoch 84/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9921 - val_loss: 2.0041 - val_accuracy: 0.7152 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 85/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9910 - val_loss: 2.0040 - val_accuracy: 0.7139 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 86/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9917 - val_loss: 2.0244 - val_accuracy: 0.7152 - lr: 0.0010 - 9s/epoch - 42ms/step
# Epoch 87/100
# 215/215 - 10s - loss: 0.0122 - accuracy: 0.9920 - val_loss: 2.0387 - val_accuracy: 0.7165 - lr: 0.0010 - 10s/epoch - 44ms/step
# Epoch 88/100
# 215/215 - 10s - loss: 0.0121 - accuracy: 0.9923 - val_loss: 2.0234 - val_accuracy: 0.7113 - lr: 0.0010 - 10s/epoch - 46ms/step
# Epoch 89/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9917 - val_loss: 2.0507 - val_accuracy: 0.7205 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 90/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9926 - val_loss: 2.0468 - val_accuracy: 0.7073 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 91/100
# 215/215 - 9s - loss: 0.0123 - accuracy: 0.9912 - val_loss: 2.0521 - val_accuracy: 0.7178 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 92/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9926 - val_loss: 2.0601 - val_accuracy: 0.7192 - lr: 0.0010 - 9s/epoch - 42ms/step
# Epoch 93/100
# 215/215 - 8s - loss: 0.0122 - accuracy: 0.9918 - val_loss: 2.0593 - val_accuracy: 0.7218 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 94/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9928 - val_loss: 2.0854 - val_accuracy: 0.7126 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 95/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9915 - val_loss: 2.0825 - val_accuracy: 0.7152 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 96/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9917 - val_loss: 2.0813 - val_accuracy: 0.7205 - lr: 0.0010 - 9s/epoch - 40ms/step
# Epoch 97/100
# 215/215 - 9s - loss: 0.0122 - accuracy: 0.9923 - val_loss: 2.0998 - val_accuracy: 0.7178 - lr: 0.0010 - 9s/epoch - 44ms/step
# Epoch 98/100
# 215/215 - 8s - loss: 0.0124 - accuracy: 0.9915 - val_loss: 2.2084 - val_accuracy: 0.7192 - lr: 0.0010 - 8s/epoch - 39ms/step
# Epoch 99/100
# 215/215 - 9s - loss: 0.0133 - accuracy: 0.9910 - val_loss: 1.9809 - val_accuracy: 0.7100 - lr: 0.0010 - 9s/epoch - 41ms/step
# Epoch 100/100
# 215/215 - 11s - loss: 0.0166 - accuracy: 0.9912 - val_loss: 1.6611 - val_accuracy: 0.7034 - lr: 0.0010 - 11s/epoch - 50ms/step
# Reducing: binary_crossentropy for epochs: 100, num_iter: 2, model: dense_model
# Epoch 1/100
# 215/215 - 7s - loss: 0.0158 - accuracy: 0.9908 - val_loss: 1.9146 - val_accuracy: 0.7047 - lr: 0.0010 - 7s/epoch - 34ms/step
# Epoch 2/100
# 215/215 - 5s - loss: 0.0154 - accuracy: 0.9911 - val_loss: 1.8924 - val_accuracy: 0.7021 - lr: 0.0010 - 5s/epoch - 22ms/step
# Epoch 3/100
# 215/215 - 6s - loss: 0.0154 - accuracy: 0.9910 - val_loss: 1.9057 - val_accuracy: 0.6969 - lr: 0.0010 - 6s/epoch - 27ms/step
# Epoch 4/100
# 215/215 - 5s - loss: 0.0157 - accuracy: 0.9902 - val_loss: 1.8960 - val_accuracy: 0.7008 - lr: 0.0010 - 5s/epoch - 25ms/step
# Epoch 5/100
# 215/215 - 5s - loss: 0.0153 - accuracy: 0.9914 - val_loss: 1.9143 - val_accuracy: 0.7087 - lr: 0.0010 - 5s/epoch - 25ms/step
# Epoch 6/100
# 215/215 - 4s - loss: 0.0156 - accuracy: 0.9899 - val_loss: 1.9218 - val_accuracy: 0.7060 - lr: 0.0010 - 4s/epoch - 20ms/step
# Epoch 7/100
# 215/215 - 5s - loss: 0.0154 - accuracy: 0.9907 - val_loss: 1.9149 - val_accuracy: 0.7073 - lr: 0.0010 - 5s/epoch - 21ms/step
# Epoch 8/100
# 215/215 - 5s - loss: 0.0153 - accuracy: 0.9915 - val_loss: 1.9239 - val_accuracy: 0.7047 - lr: 0.0010 - 5s/epoch - 24ms/step
# Epoch 9/100
# 215/215 - 6s - loss: 0.0155 - accuracy: 0.9910 - val_loss: 1.9252 - val_accuracy: 0.6995 - lr: 0.0010 - 6s/epoch - 27ms/step
# Epoch 10/100
# 215/215 - 4s - loss: 0.0155 - accuracy: 0.9908 - val_loss: 1.9164 - val_accuracy: 0.7034 - lr: 0.0010 - 4s/epoch - 20ms/step
# Epoch 11/100
# 215/215 - 5s - loss: 0.0153 - accuracy: 0.9907 - val_loss: 1.9168 - val_accuracy: 0.7073 - lr: 0.0010 - 5s/epoch - 23ms/step
# Epoch 12/100
# 215/215 - 6s - loss: 0.0153 - accuracy: 0.9914 - val_loss: 1.9337 - val_accuracy: 0.7008 - lr: 0.0010 - 6s/epoch - 28ms/step
# Epoch 13/100
# 215/215 - 4s - loss: 0.0153 - accuracy: 0.9905 - val_loss: 1.9481 - val_accuracy: 0.7034 - lr: 0.0010 - 4s/epoch - 20ms/step
# Epoch 14/100
# 215/215 - 6s - loss: 0.0152 - accuracy: 0.9898 - val_loss: 1.9476 - val_accuracy: 0.7008 - lr: 0.0010 - 6s/epoch - 27ms/step
# Epoch 15/100
# 215/215 - 5s - loss: 0.0153 - accuracy: 0.9908 - val_loss: 1.9440 - val_accuracy: 0.7008 - lr: 0.0010 - 5s/epoch - 25ms/step
# Epoch 16/100
# 215/215 - 5s - loss: 0.0153 - accuracy: 0.9911 - val_loss: 1.9434 - val_accuracy: 0.7060 - lr: 0.0010 - 5s/epoch - 24ms/step
# Epoch 17/100
# 215/215 - 5s - loss: 0.0155 - accuracy: 0.9908 - val_loss: 1.9409 - val_accuracy: 0.7100 - lr: 0.0010 - 5s/epoch - 23ms/step
# Epoch 18/100
# 215/215 - 5s - loss: 0.0153 - accuracy: 0.9910 - val_loss: 1.9422 - val_accuracy: 0.7060 - lr: 0.0010 - 5s/epoch - 21ms/step
# Epoch 19/100
# 215/215 - 5s - loss: 0.0152 - accuracy: 0.9904 - val_loss: 1.9381 - val_accuracy: 0.7113 - lr: 0.0010 - 5s/epoch - 22ms/step
# Epoch 20/100
# 215/215 - 5s - loss: 0.0154 - accuracy: 0.9901 - val_loss: 1.9419 - val_accuracy: 0.7073 - lr: 0.0010 - 5s/epoch - 23ms/step
# Epoch 21/100
# 215/215 - 6s - loss: 0.0153 - accuracy: 0.9910 - val_loss: 1.9410 - val_accuracy: 0.7113 - lr: 0.0010 - 6s/epoch - 26ms/step
# Epoch 22/100
# 215/215 - 5s - loss: 0.0153 - accuracy: 0.9905 - val_loss: 1.9540 - val_accuracy: 0.7060 - lr: 0.0010 - 5s/epoch - 22ms/step
# Epoch 23/100
# 215/215 - 7s - loss: 0.0153 - accuracy: 0.9902 - val_loss: 1.9438 - val_accuracy: 0.7126 - lr: 0.0010 - 7s/epoch - 31ms/step
# Epoch 24/100
# 215/215 - 6s - loss: 0.0155 - accuracy: 0.9899 - val_loss: 1.9357 - val_accuracy: 0.7047 - lr: 0.0010 - 6s/epoch - 27ms/step
# Epoch 25/100
# 215/215 - 5s - loss: 0.0153 - accuracy: 0.9905 - val_loss: 1.9509 - val_accuracy: 0.7034 - lr: 0.0010 - 5s/epoch - 22ms/step
# Epoch 26/100
# 215/215 - 6s - loss: 0.0154 - accuracy: 0.9907 - val_loss: 1.9560 - val_accuracy: 0.7047 - lr: 0.0010 - 6s/epoch - 26ms/step
# Epoch 27/100
# 215/215 - 5s - loss: 0.0152 - accuracy: 0.9904 - val_loss: 1.9631 - val_accuracy: 0.7100 - lr: 0.0010 - 5s/epoch - 25ms/step
# Epoch 28/100
# 215/215 - 6s - loss: 0.0154 - accuracy: 0.9902 - val_loss: 1.9602 - val_accuracy: 0.7139 - lr: 0.0010 - 6s/epoch - 27ms/step
# Epoch 29/100
# 215/215 - 4s - loss: 0.0152 - accuracy: 0.9912 - val_loss: 1.9558 - val_accuracy: 0.7073 - lr: 0.0010 - 4s/epoch - 21ms/step
# Epoch 30/100
# 215/215 - 5s - loss: 0.0153 - accuracy: 0.9917 - val_loss: 1.9609 - val_accuracy: 0.7060 - lr: 0.0010 - 5s/epoch - 25ms/step
# Epoch 31/100
# 215/215 - 5s - loss: 0.0154 - accuracy: 0.9898 - val_loss: 1.9419 - val_accuracy: 0.7021 - lr: 0.0010 - 5s/epoch - 24ms/step
# Epoch 32/100
# 215/215 - 6s - loss: 0.0151 - accuracy: 0.9912 - val_loss: 1.9533 - val_accuracy: 0.7126 - lr: 0.0010 - 6s/epoch - 28ms/step
# Epoch 33/100
# 215/215 - 6s - loss: 0.0152 - accuracy: 0.9911 - val_loss: 1.9521 - val_accuracy: 0.7060 - lr: 0.0010 - 6s/epoch - 28ms/step
# Epoch 34/100
# 215/215 - 5s - loss: 0.0152 - accuracy: 0.9914 - val_loss: 1.9664 - val_accuracy: 0.7139 - lr: 0.0010 - 5s/epoch - 25ms/step
# Epoch 35/100
# 215/215 - 5s - loss: 0.0152 - accuracy: 0.9905 - val_loss: 1.9674 - val_accuracy: 0.7113 - lr: 0.0010 - 5s/epoch - 23ms/step
# Epoch 36/100
# 215/215 - 5s - loss: 0.0153 - accuracy: 0.9917 - val_loss: 1.9649 - val_accuracy: 0.7047 - lr: 0.0010 - 5s/epoch - 21ms/step
# Epoch 37/100
# 215/215 - 5s - loss: 0.0151 - accuracy: 0.9912 - val_loss: 1.9449 - val_accuracy: 0.7008 - lr: 0.0010 - 5s/epoch - 23ms/step
# Epoch 38/100
# 215/215 - 5s - loss: 0.0151 - accuracy: 0.9908 - val_loss: 1.9563 - val_accuracy: 0.7113 - lr: 0.0010 - 5s/epoch - 25ms/step
# Epoch 39/100
# 215/215 - 5s - loss: 0.0153 - accuracy: 0.9915 - val_loss: 1.9468 - val_accuracy: 0.7139 - lr: 0.0010 - 5s/epoch - 22ms/step
# Epoch 40/100
# 215/215 - 5s - loss: 0.0152 - accuracy: 0.9895 - val_loss: 1.9556 - val_accuracy: 0.7113 - lr: 0.0010 - 5s/epoch - 25ms/step
# Epoch 41/100
# 215/215 - 5s - loss: 0.0152 - accuracy: 0.9904 - val_loss: 1.9611 - val_accuracy: 0.7047 - lr: 0.0010 - 5s/epoch - 23ms/step
# Epoch 42/100
# 215/215 - 5s - loss: 0.0150 - accuracy: 0.9908 - val_loss: 1.9831 - val_accuracy: 0.7073 - lr: 0.0010 - 5s/epoch - 23ms/step
# Epoch 43/100
# 215/215 - 5s - loss: 0.0152 - accuracy: 0.9905 - val_loss: 1.9701 - val_accuracy: 0.7047 - lr: 0.0010 - 5s/epoch - 23ms/step
# Epoch 44/100
# 215/215 - 6s - loss: 0.0152 - accuracy: 0.9911 - val_loss: 1.9742 - val_accuracy: 0.7034 - lr: 0.0010 - 6s/epoch - 26ms/step
# Epoch 45/100
# 215/215 - 5s - loss: 0.0151 - accuracy: 0.9912 - val_loss: 1.9677 - val_accuracy: 0.6942 - lr: 0.0010 - 5s/epoch - 24ms/step
# Epoch 46/100
# 215/215 - 5s - loss: 0.0150 - accuracy: 0.9911 - val_loss: 1.9778 - val_accuracy: 0.7021 - lr: 0.0010 - 5s/epoch - 25ms/step
# Epoch 47/100
# 215/215 - 5s - loss: 0.0152 - accuracy: 0.9895 - val_loss: 1.9775 - val_accuracy: 0.7100 - lr: 0.0010 - 5s/epoch - 22ms/step
# Epoch 48/100
# 215/215 - 6s - loss: 0.0149 - accuracy: 0.9911 - val_loss: 1.9884 - val_accuracy: 0.7152 - lr: 0.0010 - 6s/epoch - 28ms/step
# Epoch 49/100
# 215/215 - 5s - loss: 0.0153 - accuracy: 0.9907 - val_loss: 1.9790 - val_accuracy: 0.7100 - lr: 0.0010 - 5s/epoch - 25ms/step
# Epoch 50/100

# %% [markdown]
# ## Model Inferencing and Evaluation

# %% [markdown]
# ### Evaluation functions

# %%
def evaluate_preds(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred) * 100
    precision, recall, f1_score, info = precision_recall_fscore_support(y_true, y_pred, average="weighted")
    
    return {"accuracy": accuracy, "precision": precision, "recall": recall, "f1_score": f1_score, "info": info}

# %% [markdown]
# ### Evaluating model training

# %%
comb_pred_probs = tf.squeeze(lstm_model_pred_probs, axis=1) + tf.squeeze(bidir_lstm_model_pred_probs, axis=1)
comb_pred_probs = tf.round(comb_pred_probs / 2)
print(comb_pred_probs, comb_pred_probs.shape)

# %%
ensemble_model_metrics = evaluate_preds(y_true=val_label, y_pred=comb_pred_probs)
print(f"Ensemble model metrics: {ensemble_model_metrics}")

# %% [markdown]
# ### Inferencing on test data

# %%
test_text = test_df[["clean_text"]].to_list()
test_samples = random.sample(test_text, 10)

for test_sample in test_samples:
    pred = make_ensemble_preds(ensemble_models, test_samples)
    print(f"Pred: {int(pred)}")
    print(f"Text: \n{test_sample}\n\n")

# %% [markdown]
# ### Model saving and loading

# %%
print(f"Ensemble model 0: {ensemble_models[0]}")

ensemble_models[0].save("/models/ensemble_models/dense_model", save_format='tf')
ensemble_models[1].save("/models/ensemble_models/lstm_model", save_format='tf')
ensemble_models[2].save("/models/ensemble_models/bidir_lstm_model", save_format='tf')

loaded_ensemble_dense_model = tf.keras.models.load_model("/models/ensemble_models/dense_model")
loaded_ensemble_lstm_model = tf.keras.models.load_model("/models/ensemble_models/lstm_model")
loaded_ensemble_bidir_lstm_model = tf.keras.models.load_model("/models/ensemble_models/bidir_lstm_model")

print(loaded_ensemble_dense_model.summary(), "\n")
print(loaded_ensemble_lstm_model.summary(), "\n")
print(loaded_ensemble_bidir_lstm_model.summary(), "\n")

# %%
val_text = ""
val_label = 0

loaded_ensemble_models = [loaded_ensemble_dense_model, loaded_ensemble_lstm_model, loaded_ensemble_bidir_lstm_model]

loaded_ensemble_models.evaluate_preds(val_text, val_label)
